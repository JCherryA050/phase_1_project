# %% [markdown]
# ## IMDB /TMDB Notebook

# %% [markdown]
# In this notebook, we will use data from Box Office Mojo, IMDB, Rotten Tomatoes, TheMovieDB, and The Numbers to gain insight on how the new Microsoft Movie studio should proceed in content creation to maximize ratings, reviews, and profit. The data we are using is important and helpful to this case because the information within the data can help us narrow down which genres of movies were well received and yielded higher ratings and grossed higher earnings.

# %% [markdown]
# So it looks like we need to join/merge the different tables so we can get the names/ratings/reviews etc matching
#
# ratings with titles on tconstant
#
# once we have the titles we can join the other sets that have the movie names

# %% [markdown]
# ## business understanding top top explaining the goal and identify questions
#
# diff sections
# explain where the data comes from/source
# prep explain cleaning
# analysis/understanding - recs
# conclusion section tying it back in to general overview/main question

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Importing Data

# %% [markdown]
# Eyeballing the data sets to see how many data points we have, what we need to change, and how we can merge the sets together to get a better understanding of our data.

# %% [markdown]
# In this set, we have the average ratings for 73,856 and the number of votes for movies/'tconst'.

# %%
imdb_ratings = pd.read_csv('../zippedData/imdb.title.ratings.csv.gz')
imdb_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
imdb_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %% [markdown]
# In this data set, we have the name of different employees in the industry and their profession and what titles they're known for. Unsure of how we can use the birth and death years. Will probably drop those two

# %%
imdb_name_basics = pd.read_csv('../zippeddata/imdb.name.basics.csv.gz')
imdb_name_basics
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
#                                known_for_titles
# 0       tt0837562,tt2398241,tt0844471,tt0118553
# 1       tt0896534,tt6791238,tt0287072,tt1682940
# 2       tt1470654,tt0363631,tt0104030,tt0102898
# 3       tt0114371,tt2004304,tt1618448,tt1224387
# 4       tt0452644,tt0452692,tt3458030,tt2178256
# ...                                         ...
# 606643                                      NaN
# 606644                      tt9090932,tt8737130
# 606645                      tt8734436,tt9615610
# 606646                                      NaN
# 606647                                tt8743182
#
# [606648 rows x 6 columns]

# %% [markdown]
# In this data set, we have those same employees on 'nconst' with a more defined category of their position on each movie title 'tconst'. This set seems more useful to define what movies a certain person worked on to see the successs of a movie in relation to the artist.

# %%
imdb_principals = pd.read_csv('../zippeddata/imdb.title.principals.csv.gz')
imdb_principals
# Out:
#             tconst  ordering      nconst  category       job  \
# 0        tt0111414         1   nm0246005     actor       NaN
# 1        tt0111414         2   nm0398271  director       NaN
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor       NaN
# 4        tt0323808         1   nm3579312   actress       NaN
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor       NaN
# 1028182  tt9692684         2   nm4929530      self       NaN
# 1028183  tt9692684         3  nm10441594  director       NaN
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4            ["Beth Boothby"]
# ...                       ...
# 1028181  ["Ebenezer Scrooge"]
# 1028182   ["Herself","Regan"]
# 1028183                   NaN
# 1028184                   NaN
# 1028185                   NaN
#
# [1028186 rows x 6 columns]

# %% [markdown]
# This dataset has the names of the movies in relation to the title_id/'tconst'. We can use the 'title_id' renamed as 'tconst' to merge the sets together.

# %%
imdb_akas = pd.read_csv('../zippeddata/imdb.title.akas.csv.gz')
imdb_akas
# Out:
#          title_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg          NaN          NaN                0.0
# 1           NaN  imdbDisplay          NaN                0.0
# 2           NaN  imdbDisplay          NaN                0.0
# 3           NaN          NaN  short title                0.0
# 4           NaN  imdbDisplay          NaN                0.0
# ...         ...          ...          ...                ...
# 331698      NaN     original          NaN                1.0
# 331699       en  imdbDisplay          NaN                0.0
# 331700      NaN     original          NaN                1.0
# 331701      NaN          NaN          NaN                0.0
# 331702       en  imdbDisplay          NaN                0.0
#
# [331703 rows x 8 columns]

# %%
imdb_akas.rename(columns = {'title_id': 'tconst'}, inplace=True)
imdb_akas
# Out:
#            tconst  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg          NaN          NaN                0.0
# 1           NaN  imdbDisplay          NaN                0.0
# 2           NaN  imdbDisplay          NaN                0.0
# 3           NaN          NaN  short title                0.0
# 4           NaN  imdbDisplay          NaN                0.0
# ...         ...          ...          ...                ...
# 331698      NaN     original          NaN                1.0
# 331699       en  imdbDisplay          NaN                0.0
# 331700      NaN     original          NaN                1.0
# 331701      NaN          NaN          NaN                0.0
# 331702       en  imdbDisplay          NaN                0.0
#
# [331703 rows x 8 columns]

# %% [markdown]
# This dataset has the directors and writers associated with each movie.

# %%
imdb_crew = pd.read_csv('../zippedData/imdb.title.crew.csv.gz')
imdb_crew
# Out:
#            tconst                      directors              writers
# 0       tt0285252                      nm0899854            nm0899854
# 1       tt0438973                            NaN  nm0175726,nm1802864
# 2       tt0462036                      nm1940585            nm1940585
# 3       tt0835418                      nm0151540  nm0310087,nm0841532
# 4       tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...           ...                            ...                  ...
# 146139  tt8999974                     nm10122357           nm10122357
# 146140  tt9001390                      nm6711477            nm6711477
# 146141  tt9001494          nm10123242,nm10123248                  NaN
# 146142  tt9004986                      nm4993825            nm4993825
# 146143  tt9010172                            NaN            nm8352242
#
# [146144 rows x 3 columns]

# %% [markdown]
# This data set has genre_ids as integers. We should try to find the associating genre with the ID. It also shows the popularity, releae date, average, and vote count for different movies.

# %%
tmdb_movies = pd.read_csv('../zippedData/tmdb.movies.csv.gz', index_col=0)
tmdb_movies = tmdb_movies.drop('id', axis=1)
tmdb_movies
# Out:
#                  genre_ids original_language  \
# 0          [12, 14, 10751]                en
# 1      [14, 12, 16, 10751]                en
# 2            [12, 28, 878]                en
# 3          [16, 35, 10751]                en
# 4            [28, 878, 12]                en
# ...                    ...               ...
# 26512             [27, 18]                en
# 26513             [18, 53]                en
# 26514         [14, 28, 12]                en
# 26515      [10751, 12, 28]                en
# 26516             [53, 27]                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 8 columns]

# %% [markdown]
# ## Merging IMDB Ratings Dataset with IMDB Titles

# %% [markdown]
# Here we are merging the IMDB name/titles set with the ratings and the directors and writers.

# %%
imdb_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB

# %%
imdb_akas.rename(columns = {'title_id': 'tconst'}, inplace=True)
imdb_akas
# Out:
#            tconst  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg          NaN          NaN                0.0
# 1           NaN  imdbDisplay          NaN                0.0
# 2           NaN  imdbDisplay          NaN                0.0
# 3           NaN          NaN  short title                0.0
# 4           NaN  imdbDisplay          NaN                0.0
# ...         ...          ...          ...                ...
# 331698      NaN     original          NaN                1.0
# 331699       en  imdbDisplay          NaN                0.0
# 331700      NaN     original          NaN                1.0
# 331701      NaN          NaN          NaN                0.0
# 331702       en  imdbDisplay          NaN                0.0
#
# [331703 rows x 8 columns]

# %%
imdb_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
imdb_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
imdb_df = pd.merge(imdb_akas, imdb_ratings, on='tconst', how='left')
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331703 entries, 0 to 331702
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   tconst             331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
#  8   averagerating      261806 non-null  float64
#  9   numvotes           261806 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 27.8+ MB

# %%
people_df = pd.merge(imdb_principals, imdb_name_basics, on='nconst', how='left')
people_df
# Out:
#             tconst  ordering      nconst  category       job  \
# 0        tt0111414         1   nm0246005     actor       NaN
# 1        tt0111414         2   nm0398271  director       NaN
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor       NaN
# 4        tt0323808         1   nm3579312   actress       NaN
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor       NaN
# 1028182  tt9692684         2   nm4929530      self       NaN
# 1028183  tt9692684         3  nm10441594  director       NaN
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters           primary_name  birth_year  death_year  \
# 0                 ["The Man"]           Tommy Dysart         NaN         NaN
# 1                         NaN           Frank Howson      1952.0         NaN
# 2                         NaN  Barry Porter-Robinson         NaN         NaN
# 3                         NaN            Sean Barton      1944.0         NaN
# 4            ["Beth Boothby"]        Brittania Nicol         NaN         NaN
# ...                       ...                    ...         ...         ...
# 1028181  ["Ebenezer Scrooge"]        Kenneth Cranham      1944.0         NaN
# 1028182   ["Herself","Regan"]           Pearl Mackie      1987.0         NaN
# 1028183                   NaN              Guy Jones         NaN         NaN
# 1028184                   NaN        Sabrina Mahfouz         NaN         NaN
# 1028185                   NaN             Simmer Dim         NaN         NaN
#
#                                      primary_profession  \
# 0                                                 actor
# 1                                 actor,writer,producer
# 2                               producer,art_department
# 3        editor,editorial_department,assistant_director
# 4                                    actress,soundtrack
# ...                                                 ...
# 1028181                                actor,soundtrack
# 1028182                                         actress
# 1028183                                        director
# 1028184                                          writer
# 1028185                                        producer
#
#                                 known_for_titles
# 0        tt0093120,tt0076974,tt0084296,tt0077064
# 1        tt0104271,tt0094789,tt0102076,tt0111414
# 2        tt0290884,tt0101374,tt0111414,tt1566940
# 3        tt0402910,tt1022883,tt0086190,tt0490181
# 4                                      tt0323808
# ...                                          ...
# 1028181  tt0095294,tt0375912,tt0063385,tt0985699
# 1028182  tt9676034,tt5498354,tt0436992,tt8972256
# 1028183                                      NaN
# 1028184  tt5191128,tt3254170,tt2319282,tt8452302
# 1028185                                tt9692684
#
# [1028186 rows x 11 columns]

# %%
imdb_df_people_df = pd.merge(imdb_df, people_df, on='tconst', how='left')
imdb_df_people_df
# Out:
#             tconst  ordering_x          title region language        types  \
# 0        tt0369610          10  Джурасик свят     BG       bg          NaN
# 1        tt0369610          10  Джурасик свят     BG       bg          NaN
# 2        tt0369610          10  Джурасик свят     BG       bg          NaN
# 3        tt0369610          10  Джурасик свят     BG       bg          NaN
# 4        tt0369610          10  Джурасик свят     BG       bg          NaN
# ...            ...         ...            ...    ...      ...          ...
# 2841271  tt9880178           3  The Attention    XWW       en  imdbDisplay
# 2841272  tt9880178           3  The Attention    XWW       en  imdbDisplay
# 2841273  tt9880178           3  The Attention    XWW       en  imdbDisplay
# 2841274  tt9880178           3  The Attention    XWW       en  imdbDisplay
# 2841275  tt9880178           3  The Attention    XWW       en  imdbDisplay
#
#         attributes  is_original_title  averagerating  numvotes  ordering_y  \
# 0              NaN                0.0            7.0  539338.0        10.0
# 1              NaN                0.0            7.0  539338.0         1.0
# 2              NaN                0.0            7.0  539338.0         2.0
# 3              NaN                0.0            7.0  539338.0         3.0
# 4              NaN                0.0            7.0  539338.0         4.0
# ...            ...                ...            ...       ...         ...
# 2841271        NaN                0.0            NaN       NaN         5.0
# 2841272        NaN                0.0            NaN       NaN         6.0
# 2841273        NaN                0.0            NaN       NaN         7.0
# 2841274        NaN                0.0            NaN       NaN         8.0
# 2841275        NaN                0.0            NaN       NaN         9.0
#
#             nconst         category       job   characters  \
# 0        nm0189777         producer  producer          NaN
# 1        nm0695435            actor       NaN     ["Owen"]
# 2        nm0397171          actress       NaN   ["Claire"]
# 3        nm1339223            actor       NaN     ["Gray"]
# 4        nm0339460          actress       NaN    ["Karen"]
# ...            ...              ...       ...          ...
# 2841271  nm1567587         producer  producer          NaN
# 2841272  nm7279677  cinematographer       NaN          NaN
# 2841273  nm1341556             self       NaN  ["Himself"]
# 2841274  nm4242087             self       NaN  ["Herself"]
# 2841275  nm6571931             self       NaN  ["Herself"]
#
#                      primary_name  birth_year  death_year  \
# 0                 Patrick Crowley         NaN         NaN
# 1                     Chris Pratt      1979.0         NaN
# 2             Bryce Dallas Howard      1981.0         NaN
# 3                     Ty Simpkins         NaN         NaN
# 4                      Judy Greer      1975.0         NaN
# ...                           ...         ...         ...
# 2841271  Iñigo Fernández Ostolaza         NaN         NaN
# 2841272          Javier de Usabel         NaN         NaN
# 2841273              Jaime Jaimes         NaN         NaN
# 2841274               Amparo Malo         NaN         NaN
# 2841275           Antea Rodríguez         NaN         NaN
#
#                                        primary_profession  \
# 0          producer,assistant_director,production_manager
# 1                               actor,soundtrack,producer
# 2                                 actress,director,writer
# 3                                                   actor
# 4                             actress,producer,soundtrack
# ...                                                   ...
# 2841271                          editor,producer,director
# 2841272  camera_department,cinematographer,art_department
# 2841273                                          director
# 2841274                                           actress
# 2841275                                           actress
#
#                                 known_for_titles
# 0        tt0372183,tt1059786,tt0258463,tt0440963
# 1        tt1490017,tt0369610,tt1266020,tt2015381
# 2                  tt1454029,tt0369610,tt1800302
# 3        tt0369610,tt1300854,tt4154796,tt1591095
# 4        tt0369610,tt0337563,tt0478970,tt0988595
# ...                                          ...
# 2841271  tt0254455,tt7524694,tt9880178,tt0471112
# 2841272  tt4948838,tt7002576,tt8951078,tt4164866
# 2841273                      tt0358405,tt0451590
# 2841274                      tt5159898,tt1805202
# 2841275                      tt6614472,tt3772550
#
# [2841276 rows x 20 columns]

# %%
imdb_df_people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2841276 entries, 0 to 2841275
# Data columns (total 20 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   tconst              object
#  1   ordering_x          int64
#  2   title               object
#  3   region              object
#  4   language            object
#  5   types               object
#  6   attributes          object
#  7   is_original_title   float64
#  8   averagerating       float64
#  9   numvotes            float64
#  10  ordering_y          float64
#  11  nconst              object
#  12  category            object
#  13  job                 object
#  14  characters          object
#  15  primary_name        object
#  16  birth_year          float64
#  17  death_year          float64
#  18  primary_profession  object
#  19  known_for_titles    object
# dtypes: float64(6), int64(1), object(13)
# memory usage: 455.2+ MB

# %% [markdown]
# ## Filtering out by producer and director

# %% [markdown]
# Below we can see we have multiple names for a single move as it was released in several different markets. We want to isolate and get a single movie title we're familiar with and use that one. We made the decision to subset the US region to get a standard US release title. We filtered out all the different types of release titles as well.

# %%
directors = imdb_df_people_df[imdb_df_people_df['category'] == 'director']
directors
# Out:
#             tconst  ordering_x                                    title  \
# 5        tt0369610          10                            Джурасик свят
# 15       tt0369610          11                        Jurashikku warudo
# 25       tt0369610          12  Jurassic World: O Mundo dos Dinossauros
# 35       tt0369610          13                  O Mundo dos Dinossauros
# 45       tt0369610          14                           Jurassic World
# ...            ...         ...                                      ...
# 2841195  tt9726638           2                 Monkey King: The Volcano
# 2841203  tt9726638           3            Qi Tian Da Sheng Huo Yan Shan
# 2841221  tt9827784           1                       Sayonara kuchibiru
# 2841231  tt9827784           2                       Sayonara kuchibiru
# 2841241  tt9827784           3                            Farewell Song
#
#         region language        types   attributes  is_original_title  \
# 5           BG       bg          NaN          NaN                0.0
# 15          JP      NaN  imdbDisplay          NaN                0.0
# 25          BR      NaN  imdbDisplay          NaN                0.0
# 35          BR      NaN          NaN  short title                0.0
# 45          FR      NaN  imdbDisplay          NaN                0.0
# ...        ...      ...          ...          ...                ...
# 2841195    NaN      NaN     original          NaN                1.0
# 2841203     CN      yue  imdbDisplay          NaN                0.0
# 2841221     JP      NaN          NaN          NaN                0.0
# 2841231    NaN      NaN     original          NaN                1.0
# 2841241    XWW       en  imdbDisplay          NaN                0.0
#
#          averagerating  numvotes  ordering_y      nconst  category  job  \
# 5                  7.0  539338.0         5.0   nm1119880  director  NaN
# 15                 7.0  539338.0         5.0   nm1119880  director  NaN
# 25                 7.0  539338.0         5.0   nm1119880  director  NaN
# 35                 7.0  539338.0         5.0   nm1119880  director  NaN
# 45                 7.0  539338.0         5.0   nm1119880  director  NaN
# ...                ...       ...         ...         ...       ...  ...
# 2841195            6.0       6.0         5.0  nm10021724  director  NaN
# 2841203            6.0       6.0         5.0  nm10021724  director  NaN
# 2841221            7.7       6.0         5.0   nm0794048  director  NaN
# 2841231            7.7       6.0         5.0   nm0794048  director  NaN
# 2841241            7.7       6.0         5.0   nm0794048  director  NaN
#
#         characters     primary_name  birth_year  death_year  \
# 5              NaN  Colin Trevorrow      1976.0         NaN
# 15             NaN  Colin Trevorrow      1976.0         NaN
# 25             NaN  Colin Trevorrow      1976.0         NaN
# 35             NaN  Colin Trevorrow      1976.0         NaN
# 45             NaN  Colin Trevorrow      1976.0         NaN
# ...            ...              ...         ...         ...
# 2841195        NaN     Zhenzhao Lin         NaN         NaN
# 2841203        NaN     Zhenzhao Lin         NaN         NaN
# 2841221        NaN   Akihiko Shiota      1961.0         NaN
# 2841231        NaN   Akihiko Shiota      1961.0         NaN
# 2841241        NaN   Akihiko Shiota      1961.0         NaN
#
#                     primary_profession  \
# 5             writer,producer,director
# 15            writer,producer,director
# 25            writer,producer,director
# 35            writer,producer,director
# 45            writer,producer,director
# ...                                ...
# 2841195                director,writer
# 2841203                director,writer
# 2841221  director,writer,miscellaneous
# 2841231  director,writer,miscellaneous
# 2841241  director,writer,miscellaneous
#
#                                 known_for_titles
# 5        tt0369610,tt4881806,tt4572792,tt1862079
# 15       tt0369610,tt4881806,tt4572792,tt1862079
# 25       tt0369610,tt4881806,tt4572792,tt1862079
# 35       tt0369610,tt4881806,tt4572792,tt1862079
# 45       tt0369610,tt4881806,tt4572792,tt1862079
# ...                                          ...
# 2841195  tt9477132,tt8787116,tt9477338,tt9726638
# 2841203  tt9477132,tt8787116,tt9477338,tt9726638
# 2841221  tt0780503,tt0297905,tt0208178,tt0210651
# 2841231  tt0780503,tt0297905,tt0208178,tt0210651
# 2841241  tt0780503,tt0297905,tt0208178,tt0210651
#
# [348492 rows x 20 columns]

# %%
producers = imdb_df_people_df[imdb_df_people_df['category'] == 'producer']
producers
# Out:
#             tconst  ordering_x                                    title  \
# 0        tt0369610          10                            Джурасик свят
# 10       tt0369610          11                        Jurashikku warudo
# 20       tt0369610          12  Jurassic World: O Mundo dos Dinossauros
# 30       tt0369610          13                  O Mundo dos Dinossauros
# 40       tt0369610          14                           Jurassic World
# ...            ...         ...                                      ...
# 2841242  tt9827784           3                            Farewell Song
# 2841243  tt9827784           3                            Farewell Song
# 2841251  tt9880178           1                              La atención
# 2841261  tt9880178           2                              La atención
# 2841271  tt9880178           3                            The Attention
#
#         region language        types   attributes  is_original_title  \
# 0           BG       bg          NaN          NaN                0.0
# 10          JP      NaN  imdbDisplay          NaN                0.0
# 20          BR      NaN  imdbDisplay          NaN                0.0
# 30          BR      NaN          NaN  short title                0.0
# 40          FR      NaN  imdbDisplay          NaN                0.0
# ...        ...      ...          ...          ...                ...
# 2841242    XWW       en  imdbDisplay          NaN                0.0
# 2841243    XWW       en  imdbDisplay          NaN                0.0
# 2841251    NaN      NaN     original          NaN                1.0
# 2841261     ES      NaN          NaN          NaN                0.0
# 2841271    XWW       en  imdbDisplay          NaN                0.0
#
#          averagerating  numvotes  ordering_y     nconst  category       job  \
# 0                  7.0  539338.0        10.0  nm0189777  producer  producer
# 10                 7.0  539338.0        10.0  nm0189777  producer  producer
# 20                 7.0  539338.0        10.0  nm0189777  producer  producer
# 30                 7.0  539338.0        10.0  nm0189777  producer  producer
# 40                 7.0  539338.0        10.0  nm0189777  producer  producer
# ...                ...       ...         ...        ...       ...       ...
# 2841242            7.7       6.0         6.0  nm0624375  producer  producer
# 2841243            7.7       6.0         7.0  nm4151154  producer  producer
# 2841251            NaN       NaN         5.0  nm1567587  producer  producer
# 2841261            NaN       NaN         5.0  nm1567587  producer  producer
# 2841271            NaN       NaN         5.0  nm1567587  producer  producer
#
#         characters              primary_name  birth_year  death_year  \
# 0              NaN           Patrick Crowley         NaN         NaN
# 10             NaN           Patrick Crowley         NaN         NaN
# 20             NaN           Patrick Crowley         NaN         NaN
# 30             NaN           Patrick Crowley         NaN         NaN
# 40             NaN           Patrick Crowley         NaN         NaN
# ...            ...                       ...         ...         ...
# 2841242        NaN          Hiroyuki Negishi         NaN         NaN
# 2841243        NaN               Mariko Seto         NaN         NaN
# 2841251        NaN  Iñigo Fernández Ostolaza         NaN         NaN
# 2841261        NaN  Iñigo Fernández Ostolaza         NaN         NaN
# 2841271        NaN  Iñigo Fernández Ostolaza         NaN         NaN
#
#                                      primary_profession  \
# 0        producer,assistant_director,production_manager
# 10       producer,assistant_director,production_manager
# 20       producer,assistant_director,production_manager
# 30       producer,assistant_director,production_manager
# 40       producer,assistant_director,production_manager
# ...                                                 ...
# 2841242                   animation_department,producer
# 2841243                          producer,miscellaneous
# 2841251                        editor,producer,director
# 2841261                        editor,producer,director
# 2841271                        editor,producer,director
#
#                                 known_for_titles
# 0        tt0372183,tt1059786,tt0258463,tt0440963
# 10       tt0372183,tt1059786,tt0258463,tt0440963
# 20       tt0372183,tt1059786,tt0258463,tt0440963
# 30       tt0372183,tt1059786,tt0258463,tt0440963
# 40       tt0372183,tt1059786,tt0258463,tt0440963
# ...                                          ...
# 2841242  tt1720905,tt0468795,tt0208178,tt0976060
# 2841243  tt9827784,tt0466405,tt0965567,tt2842050
# 2841251  tt0254455,tt7524694,tt9880178,tt0471112
# 2841261  tt0254455,tt7524694,tt9880178,tt0471112
# 2841271  tt0254455,tt7524694,tt9880178,tt0471112
#
# [425207 rows x 20 columns]

# %% [markdown]
# ## Filtering out Duplicated and Foreign Names

# %% [markdown]
# Below we can see we have multiple names for a single movie/'tconst' as it was released in several different markets. We want to isolate and get a single movie title we're familiar with and use that one. We made the decision to subset the US region to get a standard US release title. We filtered out all the different types of release titles as well.

# %%
imdb_df['tconst'].value_counts()
# Out:
# tt2488496    61
# tt1201607    55
# tt2310332    55
# tt1790809    53
# tt2278871    53
#              ..
# tt6622288     1
# tt2414424     1
# tt4522606     1
# tt7122922     1
# tt6067858     1
# Name: tconst, Length: 122302, dtype: int64

# %%
imdb_df['numvotes'].dropna(inplace=True)

# %%
imdb_df['numvotes'].describe().astype(int)
# Out:
# count     261806
# mean       28780
# std        94734
# min            5
# 25%           62
# 50%          617
# 75%         7505
# max      1841066
# Name: numvotes, dtype: int32

# %%
np.log(imdb_df['numvotes'].dropna())
# Out:
# 0         13.198098
# 1         13.198098
# 2         13.198098
# 3         13.198098
# 4         13.198098
#             ...
# 331692     1.791759
# 331693     1.791759
# 331697     1.791759
# 331698     1.791759
# 331699     1.791759
# Name: numvotes, Length: 261806, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.boxplot(np.log(imdb_df['numvotes'].dropna()));
ax.set_yticks(np.arange(2, 15, 2))
#ax.set_yticklabels(10.0**np.arange(2, 15))
#ax.ticklabel_format(axis='y', style='sci')
ax.set_yticklabels(['10^2', '10^4', '10^6', '10^8', '10^10', '10^12', '10^14']);

# %% [markdown]
# Here we will sort out films with less than 1,000 votes

# %%
imdb_df_cleaned = imdb_df[imdb_df['numvotes'] >= 1000]

# %%
fig, ax = plt.subplots()
ax.hist(imdb_df['numvotes'], bins=20);
# Out:
# C:\Users\Erin Vu\anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Erin Vu\anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# We sort the set descending by the average rating to get the higher rating of the movie for each 'tconst'

# %%
imdb_df_cleaned = imdb_df_cleaned.sort_values(by='averagerating', ascending=False)
imdb_df_cleaned
# Out:
#            tconst  ordering                              title region  \
# 249600  tt7131622        19               Tenkrát v Hollywoodu     CZ
# 249603  tt7131622        21      Once Upon a Time in Hollywood    XWW
# 249604  tt7131622        22  Once Upon a Time ... in Hollywood     US
# 249616  tt7131622         6      Once Upon a Time in Hollywood     DE
# 249593  tt7131622        12        Bilo jednom... u Hollywoodu     HR
# ...           ...       ...                                ...    ...
# 287465  tt4404474         1                     Kartoffelsalat    NaN
# 259492  tt8081062         4               Li hai le, wo de guo     CN
# 299597  tt9165634         1                     Hanum & Rangga    XWW
# 299598  tt9165634         2   Hanum & Rangga: Faith & The City     ID
# 299599  tt9165634         3   Hanum & Rangga: Faith & The City    NaN
#
#        language        types attributes  is_original_title  directors  \
# 249600      NaN  imdbDisplay        NaN                0.0  nm0000233
# 249603       en  alternative        NaN                0.0  nm0000233
# 249604      NaN          NaN        NaN                0.0  nm0000233
# 249616      NaN  imdbDisplay        NaN                0.0  nm0000233
# 249593      NaN  imdbDisplay        NaN                0.0  nm0000233
# ...         ...          ...        ...                ...        ...
# 287465      NaN     original        NaN                1.0  nm5673990
# 259492      NaN          NaN        NaN                0.0  nm2863763
# 299597       en  imdbDisplay        NaN                0.0  nm3447204
# 299598      NaN          NaN        NaN                0.0  nm3447204
# 299599      NaN     original        NaN                1.0  nm3447204
#
#                               writers  averagerating  numvotes
# 249600                      nm0000233            9.7    5600.0
# 249603                      nm0000233            9.7    5600.0
# 249604                      nm0000233            9.7    5600.0
# 249616                      nm0000233            9.7    5600.0
# 249593                      nm0000233            9.7    5600.0
# ...                               ...            ...       ...
# 287465            nm5756431,nm5673990            1.3    6249.0
# 259492                            NaN            1.3    3244.0
# 299597  nm8554511,nm7725390,nm3447204            1.2    3445.0
# 299598  nm8554511,nm7725390,nm3447204            1.2    3445.0
# 299599  nm8554511,nm7725390,nm3447204            1.2    3445.0
#
# [116956 rows x 12 columns]

# %% [markdown]
# Here we are subsetting the US region.

# %%
imdb_df = imdb_df[imdb_df['region'] == 'US']

# %% [markdown]
# Here we can see that there's different titles for a single movie so we can filter these extra ones out

# %%
imdb_df['attributes'].value_counts()
# Out:
# new title                           532
# informal English title              209
# literal English title               180
# complete title                      173
# alternative spelling                147
#                                    ...
# DVD menu title                        1
# transliterated ISO-LATIN-1 title      1
# first episode title                   1
# TV listings title                     1
# informal literal title                1
# Name: attributes, Length: 64, dtype: int64

# %%
imdb_df['types'].value_counts()
# Out:
# imdbDisplay    3203
# working        2020
# alternative     966
# dvd             233
# festival        218
# tv               33
# video            25
# original          3
# Name: types, dtype: int64

# %%
imdb_df = imdb_df[imdb_df['attributes'] != 'fake working title']
imdb_df = imdb_df[imdb_df['attributes'] != 'informal short title']
imdb_df = imdb_df[imdb_df['attributes'] != 'promotional title']
imdb_df = imdb_df[imdb_df['types'] != 'working']
imdb_df = imdb_df[imdb_df['attributes'] != 'IMAX version']
imdb_df = imdb_df[imdb_df['attributes'] != 'poster title']
imdb_df = imdb_df[imdb_df['attributes'] != 'informal title']
imdb_df = imdb_df[imdb_df['attributes'] != '3-D version']
imdb_df = imdb_df[imdb_df['attributes'] != 'director\'s cut']
imdb_df = imdb_df[imdb_df['attributes'] != 'alternative spelling']
imdb_df = imdb_df[imdb_df['attributes'] != 'informal alternative title']
imdb_df = imdb_df[imdb_df['attributes'] != 'long title']
imdb_df = imdb_df[imdb_df['attributes'] != 'short title']
imdb_df = imdb_df[imdb_df['types'] != 'alternative']

# %%
imdb_df = imdb_df.sort_values(by='numvotes', ascending=False)
imdb_df
# Out:
#            tconst  ordering                                title region  \
# 8298    tt1375666         8                            Inception     US
# 8270    tt1375666        24                            Inception     US
# 13595   tt0816692        14                         Interstellar     US
# 13612   tt0816692         2                         Interstellar     US
# 47379   tt1853728        11                     Django Unchained     US
# ...           ...       ...                                  ...    ...
# 331539  tt7385718         1                         Conway Pride     US
# 331574  tt8855960         1                          Straight Up     US
# 331582  tt8901666         1                    The Journey Ahead     US
# 331686  tt9705860         1  Dusan Vukotic Croatian Oscar Winner     US
# 331694  tt9755806         1                            Big Shark     US
#
#        language        types attributes  is_original_title  averagerating  \
# 8298         en          NaN        NaN                0.0            8.8
# 8270        NaN  imdbDisplay        NaN                0.0            8.8
# 13595       NaN          NaN        NaN                0.0            8.6
# 13612        en          NaN        NaN                0.0            8.6
# 47379       NaN  imdbDisplay        NaN                0.0            8.4
# ...         ...          ...        ...                ...            ...
# 331539      NaN          NaN        NaN                0.0            NaN
# 331574      NaN          NaN        NaN                0.0            NaN
# 331582      NaN  imdbDisplay        NaN                0.0            NaN
# 331686      NaN  imdbDisplay        NaN                0.0            NaN
# 331694      NaN          NaN        NaN                0.0            NaN
#
#          numvotes
# 8298    1841066.0
# 8270    1841066.0
# 13595   1299334.0
# 13612   1299334.0
# 47379   1211405.0
# ...           ...
# 331539        NaN
# 331574        NaN
# 331582        NaN
# 331686        NaN
# 331694        NaN
#
# [47807 rows x 10 columns]

# %%
imdb_df.iloc[100:150]
# Out:
#            tconst  ordering                                      title region  \
# 190578  tt4154796        18                          Avengers: Endgame     US
# 69478   tt2310332        49  The Hobbit: The Battle of the Five Armies     US
# 38361   tt1570728        22                       Crazy, Stupid, Love.     US
# 230754  tt3783958        41                                 La La Land     US
# 108115  tt3460252        25                          The Hateful Eight     US
# 523     tt1343092        13                           The Great Gatsby     US
# 68066   tt1411697        16                       The Hangover Part II     US
# 92237   tt1229238        38       Mission: Impossible - Ghost Protocol     US
# 58765   tt2250912         6                     Spider-Man: Homecoming     US
# 19077   tt0470752        11                                 Ex Machina     US
# 11584   tt1659337        28            The Perks of Being a Wallflower     US
# 28726   tt1800241        31                            American Hustle     US
# 317961  tt2872718        29                               Nightcrawler     US
# 151833  tt1291584         8                                    Warrior     US
# 140825  tt0790636        19                         Dallas Buyers Club     US
# 61285   tt2179136        17                            American Sniper     US
# 81497   tt1430132         6                              The Wolverine     US
# 212182  tt5052448        15                                    Get Out     US
# 12464   tt1840309         9                                  Divergent     US
# 51793   tt1499658        14                            Horrible Bosses     US
# 86875   tt1457767        24                              The Conjuring     US
# 86892   tt1457767         3                              The Conjuring     US
# 116889  tt1535108        10                                    Elysium     US
# 38143   tt1515091        14         Sherlock Holmes: A Game of Shadows     US
# 130998  tt1979320         6                                       Rush     US
# 30552   tt1454029        23                                   The Help     US
# 292156  tt5463162        11                                        DP2     US
# 292170  tt5463162        24                                 Deadpool 2     US
# 292185  tt5463162         7                       Once Upon a Deadpool     US
# 292183  tt5463162         5                                 Deadpool 2     US
# 117965  tt2103281        18             Dawn of the Planet of the Apes     US
# 6890    tt1872181        14                   The Amazing Spider-Man 2     US
# 84112   tt1568346        39            The Girl with the Dragon Tattoo     US
# 84098   tt1568346        26            The Girl with the Dragon Tattoo     US
# 51888   tt1535109        18                           Captain Phillips     US
# 36399   tt1790864        21                            The Maze Runner     US
# 200407  tt2948356        32                                   Zootopia     US
# 184596  tt2713180         2                                       Fury     US
# 42270   tt1951265        19      The Hunger Games: Mockingjay - Part 1     US
# 150034  tt1856101        31                          Blade Runner 2049     US
# 150019  tt1856101        18                          Blade Runner 2049     US
# 68594   tt1723121        35                          We're the Millers     US
# 58670   tt2245084        16                                 Big Hero 6     US
# 90420   tt2119532        25                              Hacksaw Ridge     US
# 68039   tt1399103        47             Transformers: Dark of the Moon     US
# 68046   tt1399103         8                                   D.O.T.M.     US
# 68033   tt1399103        41             Transformers: Dark of the Moon     US
# 113461  tt0398286        16                                    Tangled     US
# 83498   tt3183660         6    Fantastic Beasts and Where to Find Them     US
# 6993    tt1895587        26                                  Spotlight     US
#
#        language        types                attributes  is_original_title  \
# 190578       en          NaN                       NaN                0.0
# 69478       NaN  imdbDisplay                       NaN                0.0
# 38361       NaN          NaN                       NaN                0.0
# 230754      NaN  imdbDisplay                       NaN                0.0
# 108115      NaN  imdbDisplay                       NaN                0.0
# 523         NaN  imdbDisplay                       NaN                0.0
# 68066       NaN  imdbDisplay                       NaN                0.0
# 92237       NaN          NaN                       NaN                0.0
# 58765       NaN          NaN                       NaN                0.0
# 19077       NaN  imdbDisplay                       NaN                0.0
# 11584       NaN  imdbDisplay                       NaN                0.0
# 28726       NaN          NaN                       NaN                0.0
# 317961      NaN  imdbDisplay                       NaN                0.0
# 151833      NaN  imdbDisplay                       NaN                0.0
# 140825      NaN  imdbDisplay                       NaN                0.0
# 61285       NaN  imdbDisplay                       NaN                0.0
# 81497       NaN          NaN                       NaN                0.0
# 212182      NaN  imdbDisplay                       NaN                0.0
# 12464       NaN  imdbDisplay                       NaN                0.0
# 51793       NaN          NaN                       NaN                0.0
# 86875       NaN          NaN                       NaN                0.0
# 86892        en          NaN                       NaN                0.0
# 116889      NaN  imdbDisplay                       NaN                0.0
# 38143       NaN          NaN                       NaN                0.0
# 130998      NaN  imdbDisplay                       NaN                0.0
# 30552       NaN  imdbDisplay                       NaN                0.0
# 292156      NaN          NaN  promotional abbreviation                0.0
# 292170      NaN          NaN                       NaN                0.0
# 292185      NaN          NaN               cut version                0.0
# 292183       en          NaN                       NaN                0.0
# 117965      NaN          NaN                       NaN                0.0
# 6890        NaN          NaN                       NaN                0.0
# 84112        en          NaN                       NaN                0.0
# 84098       NaN  imdbDisplay                       NaN                0.0
# 51888       NaN  imdbDisplay                       NaN                0.0
# 36399       NaN  imdbDisplay                       NaN                0.0
# 200407      NaN  imdbDisplay                       NaN                0.0
# 184596      NaN          NaN                       NaN                0.0
# 42270       NaN          NaN                       NaN                0.0
# 150034       en          NaN                       NaN                0.0
# 150019      NaN          NaN                       NaN                0.0
# 68594       NaN  imdbDisplay                       NaN                0.0
# 58670       NaN  imdbDisplay                       NaN                0.0
# 90420       NaN  imdbDisplay                       NaN                0.0
# 68039       NaN          NaN                       NaN                0.0
# 68046       NaN          NaN  promotional abbreviation                0.0
# 68033        en          NaN                       NaN                0.0
# 113461      NaN  imdbDisplay                       NaN                0.0
# 83498       NaN  imdbDisplay                       NaN                0.0
# 6993        NaN  imdbDisplay                       NaN                0.0
#
#         averagerating  numvotes
# 190578            8.8  441135.0
# 69478             7.4  438621.0
# 38361             7.4  436830.0
# 230754            8.0  436070.0
# 108115            7.8  434966.0
# 523               7.3  433165.0
# 68066             6.5  432800.0
# 92237             7.4  428142.0
# 58765             7.5  426302.0
# 19077             7.7  424542.0
# 11584             8.0  422671.0
# 28726             7.2  418221.0
# 317961            7.9  404476.0
# 151833            8.2  403755.0
# 140825            8.0  402462.0
# 61285             7.3  401915.0
# 81497             6.7  401286.0
# 212182            7.7  400474.0
# 12464             6.7  399703.0
# 51793             6.9  398695.0
# 86875             7.5  397233.0
# 86892             7.5  397233.0
# 116889            6.6  395572.0
# 38143             7.5  394189.0
# 130998            8.1  393437.0
# 30552             8.1  392699.0
# 292156            7.8  391735.0
# 292170            7.8  391735.0
# 292185            7.8  391735.0
# 292183            7.8  391735.0
# 117965            7.6  390199.0
# 6890              6.6  388363.0
# 84112             7.8  387580.0
# 84098             7.8  387580.0
# 51888             7.8  387402.0
# 36399             6.8  387038.0
# 200407            8.0  383446.0
# 184596            7.6  381993.0
# 42270             6.6  379050.0
# 150034            8.0  376241.0
# 150019            8.0  376241.0
# 68594             7.0  371759.0
# 58670             7.8  371204.0
# 90420             8.1  366904.0
# 68039             6.2  366409.0
# 68046             6.2  366409.0
# 68033             6.2  366409.0
# 113461            7.8  366366.0
# 83498             7.3  365353.0
# 6993              8.1  365110.0

# %%
imdb_df = imdb_df.drop_duplicates(subset=['tconst'], keep='first')
imdb_df
# Out:
#            tconst  ordering                                title region  \
# 8298    tt1375666         8                            Inception     US
# 13595   tt0816692        14                         Interstellar     US
# 47379   tt1853728        11                     Django Unchained     US
# 81125   tt0848228        36                         The Avengers     US
# 94472   tt0993846        12              The Wolf of Wall Street     US
# ...           ...       ...                                  ...    ...
# 331539  tt7385718         1                         Conway Pride     US
# 331574  tt8855960         1                          Straight Up     US
# 331582  tt8901666         1                    The Journey Ahead     US
# 331686  tt9705860         1  Dusan Vukotic Croatian Oscar Winner     US
# 331694  tt9755806         1                            Big Shark     US
#
#        language        types attributes  is_original_title  averagerating  \
# 8298         en          NaN        NaN                0.0            8.8
# 13595       NaN          NaN        NaN                0.0            8.6
# 47379       NaN  imdbDisplay        NaN                0.0            8.4
# 81125       NaN  imdbDisplay        NaN                0.0            8.1
# 94472       NaN  imdbDisplay        NaN                0.0            8.2
# ...         ...          ...        ...                ...            ...
# 331539      NaN          NaN        NaN                0.0            NaN
# 331574      NaN          NaN        NaN                0.0            NaN
# 331582      NaN  imdbDisplay        NaN                0.0            NaN
# 331686      NaN  imdbDisplay        NaN                0.0            NaN
# 331694      NaN          NaN        NaN                0.0            NaN
#
#          numvotes
# 8298    1841066.0
# 13595   1299334.0
# 47379   1211405.0
# 81125   1183655.0
# 94472   1035358.0
# ...           ...
# 331539        NaN
# 331574        NaN
# 331582        NaN
# 331686        NaN
# 331694        NaN
#
# [46709 rows x 10 columns]

# %% [markdown]
# Below we can see we only have 1 'tconst' now for each  movie

# %%
imdb_df['tconst'].value_counts()
# Out:
# tt2874084    1
# tt3237082    1
# tt2946762    1
# tt2975986    1
# tt4513110    1
#             ..
# tt2187590    1
# tt2271697    1
# tt2322540    1
# tt2261547    1
# tt4709596    1
# Name: tconst, Length: 46709, dtype: int64

# %% [markdown]
# Below we can see we have multiple titles still but they can be different movies with the same title.

# %%
imdb_df['title'].value_counts()
# Out:
# Gone                                                9
# Broken                                              9
# The Return                                          9
# Collision                                           7
# Lucky                                               7
#                                                    ..
# The Black Eyed Peas: The Beginning of the E.N.D.    1
# The Land of Flowers                                 1
# Spotlight                                           1
# Shiloh: Fiery Trial                                 1
# Caffeine                                            1
# Name: title, Length: 44631, dtype: int64

# %% [markdown]
# ## Merging the Movies Database to our IMDB dataframe on Title

# %% [markdown]
# Here we merged the two different datasets to get the other information to match in the table

# %%
tmdb_movies
# Out:
#                  genre_ids original_language  \
# 0          [12, 14, 10751]                en
# 1      [14, 12, 16, 10751]                en
# 2            [12, 28, 878]                en
# 3          [16, 35, 10751]                en
# 4            [28, 878, 12]                en
# ...                    ...               ...
# 26512             [27, 18]                en
# 26513             [18, 53]                en
# 26514         [14, 28, 12]                en
# 26515      [10751, 12, 28]                en
# 26516             [53, 27]                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 8 columns]

# %%
tmdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   original_language  26517 non-null  object
#  2   original_title     26517 non-null  object
#  3   popularity         26517 non-null  float64
#  4   release_date       26517 non-null  object
#  5   title              26517 non-null  object
#  6   vote_average       26517 non-null  float64
#  7   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.8+ MB

# %%
tmdb_movies_sorted = tmdb_movies['title'] == tmdb_movies['original_title']
tmdb_movies_sorted.value_counts()
# Out:
# True     23973
# False     2544
# dtype: int64

# %% [markdown]
# Below, we can see the titles are mismatched on original_title having generally the international title and the title column having the English title.

# %%
tmdb_movies_not_equal = tmdb_movies[tmdb_movies['title'] != tmdb_movies['original_title']]
tmdb_movies_not_equal[:60]
# Out:
#                    genre_ids original_language  \
# 14                  [27, 80]                en
# 49               [10749, 18]                es
# 67       [16, 12, 14, 10751]                en
# 70     [80, 18, 9648, 10749]                es
# 75                      [16]                ja
# 79        [28, 53, 80, 9648]                sv
# 84         [12, 14, 16, 878]                ja
# 87    [18, 28, 53, 80, 9648]                sv
# 98        [14, 12, 28, 9648]                fr
# 103             [28, 18, 36]                ja
# 110             [28, 53, 80]                fr
# 122             [18, 28, 36]                cn
# 167          [16, 10751, 35]                de
# 169              [10749, 35]                fr
# 171                     [35]                it
# 188      [10752, 18, 36, 28]                ru
# 191             [28, 12, 53]                en
# 193             [28, 80, 53]                fr
# 195              [18, 10749]                es
# 198             [18, 53, 80]                ja
# 199      [14, 18, 27, 10749]                de
# 210     [14, 18, 28, 53, 16]                ja
# 215                 [16, 18]                fr
# 221                 [27, 53]                es
# 225          [35, 18, 10749]                it
# 230         [18, 28, 53, 80]                fr
# 241                     [18]                it
# 242             [18, 28, 53]                zh
# 251             [28, 35, 80]                hi
# 259                     [35]                fr
# 262              [35, 10749]                fr
# 263         [28, 53, 80, 18]                fr
# 266  [28, 12, 18, 36, 10752]                de
# 271                 [36, 28]                zh
# 273                 [18, 28]                no
# 274             [28, 35, 12]                zh
# 284                     [18]                fr
# 287          [18, 35, 10749]                ko
# 291                 [27, 53]                es
# 310         [14, 18, 27, 35]                it
# 314                     [35]                fr
# 324                 [18, 36]                zh
# 329                     [35]                ru
# 340          [35, 18, 10749]                it
# 357              [10749, 35]                de
# 358              [10751, 16]                ja
# 363                     [35]                fr
# 367          [18, 36, 10752]                no
# 371             [35, 28, 80]                fr
# 374                 [16, 35]                da
# 375              [35, 10749]                fr
# 383              [35, 10749]                fr
# 391                 [27, 53]                ja
# 400                     [28]                cn
# 402                     [14]                fi
# 407             [18, 27, 53]                fr
# 409             [28, 18, 53]                es
# 411                     [99]                fr
# 417                     [18]                hi
# 422                     [12]                ja
#
#                                       original_title  popularity release_date  \
# 14                                            Saw 3D      20.370   2010-10-28
# 49                        Tres metros sobre el cielo      13.721   2010-12-20
# 67               Arthur 3: la guerre des deux mondes      12.679   2010-08-22
# 70                            El secreto de sus ojos      12.531   2010-04-16
# 75                                           サマーウォーズ      12.275   2010-10-13
# 79                         Luftslottet som sprängdes      12.235   2010-10-29
# 84                                              ゲド戦記      12.005   2010-08-13
# 87                       Flickan som lekte med elden      11.655   2010-07-09
# 98   Les Aventures extraordinaires d'Adèle Blanc-Sec      11.221   2010-04-14
# 103                                                乱      10.885   1985-09-26
# 110                          Banlieue 13 - Ultimatum      10.661   2010-02-05
# 122                                               葉問      10.230   2010-10-01
# 167                              Konferenz der Tiere       9.258   2010-10-07
# 169                                      L'arnacoeur       9.241   2010-09-10
# 171                                 Benvenuti al sud       9.188   2010-12-20
# 188                               Брестская крепость       8.769   2010-11-11
# 191                                       Titanic II       8.729   2010-08-24
# 193                                       L'Immortel       8.697   2010-03-24
# 195                               Habitación en Roma       8.682   2010-11-11
# 198                                           冷たい熱帯魚       8.582   2010-07-05
# 199                               Wir sind die Nacht       8.570   2010-11-11
# 210                                            レドライン       8.436   2010-09-23
# 215                                  L'illusionniste       8.404   2010-12-25
# 221                                Los ojos de Julia       8.268   2010-10-29
# 225                                     Mine vaganti       8.202   2010-04-28
# 230                               L'Instinct de mort       8.131   2010-08-27
# 241                   La solitudine dei numeri primi       7.959   2010-10-10
# 242                                              錦衣衛       7.948   2010-02-04
# 251                                           दबंग्ग       7.831   2010-09-10
# 259                               Tout ce qui Brille       7.756   2010-12-03
# 262                      L'Amour, c'est mieux à deux       7.701   2010-06-29
# 263                              L'ennemi public n°1       7.700   2010-09-03
# 266                                   Der rote Baron       7.676   2010-02-11
# 271                                               剑雨       7.621   2010-09-01
# 273                                 Kongen av Bastøy       7.616   2010-12-20
# 274                                             大兵小将       7.607   2010-02-14
# 284                                Mes chères études       7.394   2010-11-11
# 287                                           김씨 표류기       7.368   2010-02-05
# 291                                     Secuestrados       7.297   2010-06-17
# 310                             Dellamorte Dellamore       7.078   1996-04-26
# 314                                  Rien à déclarer       6.978   2010-12-20
# 324                                               孔子       6.706   2010-03-18
# 329                            О чём говорят мужчины       6.675   2010-11-11
# 340                               Cosa voglio di più       6.530   2010-06-06
# 357             Groupies bleiben nicht zum Frühstück       6.320   2010-10-10
# 358                                     レイトン教授と永遠の歌姫       6.308   2010-12-31
# 363                           Les Femmes du 6e étage       6.281   2010-12-20
# 367                                        Max Manus       6.230   2010-09-03
# 371                                         Coursier       6.195   2010-02-24
# 374                                   Terkel i knibe       6.135   2010-03-26
# 375                               De vrais mensonges       6.092   2010-12-21
# 383                                  L'Âge de raison       5.982   2010-07-28
# 391                                       Gurotesuku       5.828   2010-07-16
# 400                                               狼牙       5.716   2010-12-28
# 402                                     Rare Exports       5.704   2010-12-03
# 407                            Les 7 jours du talion       5.575   2010-07-28
# 409                        Balada triste de trompeta       5.552   2011-08-19
# 411                                            Bébés       5.450   2010-05-07
# 417                                             उड़ान       5.376   2010-06-17
# 422                                          時をかける少女       5.319   2010-09-12
#
#                                                title  vote_average  vote_count
# 14                            Saw: The Final Chapter           6.0        1488
# 49                          Three Steps Above Heaven           7.5         960
# 67               Arthur 3: The War of the Two Worlds           5.6         865
# 70                          The Secret in Their Eyes           7.9        1141
# 75                                       Summer Wars           7.5         447
# 79             The Girl Who Kicked the Hornet's Nest           7.0         705
# 84                               Tales from Earthsea           6.6         502
# 87                     The Girl Who Played with Fire           7.0         881
# 98   The Extraordinary Adventures of Adèle Blanc-Sec           6.0         671
# 103                                              Ran           8.1         600
# 110                           District 13: Ultimatum           6.1         555
# 122                                           Ip Man           7.7        1906
# 167                                   Animals United           5.4         151
# 169                                     Heartbreaker           6.6         761
# 171                             Welcome to the South           6.7        1071
# 188                                  Fortress of War           7.3          75
# 191                                        Titanic 2           3.2          90
# 193                                       22 Bullets           6.5         508
# 195                                     Room in Rome           6.1         236
# 198                                        Cold Fish           6.6         113
# 199                                 We Are the Night           6.2         129
# 210                                          Redline           7.4         110
# 215                                  The Illusionist           7.4         280
# 221                                     Julia's Eyes           6.7         415
# 225                                    Loose Cannons           7.4         310
# 230                         Mesrine: Killer Instinct           7.4         434
# 241                    The Solitude of Prime Numbers           5.8         218
# 242                                        14 Blades           6.6          87
# 251                                          Dabangg           6.2          73
# 259                                All That Glitters           6.4         456
# 262                                 The Perfect Date           5.6         118
# 263                         Mesrine: Public Enemy #1           7.4         404
# 266                                    The Red Baron           6.5         111
# 271                               Reign of Assassins           6.8          87
# 273                           King of Devil's Island           7.3          96
# 274                               Little Big Soldier           6.8         123
# 284                                 Student Services           4.8          67
# 287                             Castaway on the Moon           8.1         259
# 291                                        Kidnapped           6.3          98
# 310                                     Cemetery Man           7.1         192
# 314                               Nothing to Declare           5.8         602
# 324                                        Confucius           5.9          45
# 329                              What Men Talk About           7.7          71
# 340                                      Come Undone           5.6          49
# 357                               Single By Contract           6.9         104
# 358            Professor Layton and the Eternal Diva           7.7          78
# 363                       The Women on the 6th Floor           6.7         183
# 367                            Max Manus: Man of War           7.1         114
# 371                                    Paris Express           4.9          74
# 374                                Terkel in Trouble           6.4          39
# 375                                   Beautiful Lies           5.8          70
# 383              With Love... from the Age of Reason           5.3          64
# 391                                        Grotesque           5.3          69
# 400                               Legendary Assassin           6.2          33
# 402                   Rare Exports: A Christmas Tale           6.5         233
# 407                                       Seven Days           6.3          76
# 409                                  The Last Circus           6.7         177
# 411                                           Babies           7.0          77
# 417                                            Udaan           7.2          83
# 422  Time Traveller: The Girl Who Leapt Through Time           6.3          26

# %%
tmdb_movies
print(f'tmbd_movies has {len(tmdb_movies)} records')
# Out:
# tmbd_movies has 26517 records

# %%
print(f'imdb_df has {len(imdb_df)} records')
# Out:
# imdb_df has 46709 records

# %%
imdb_tmdb = pd.merge(imdb_df, tmdb_movies, on='title', how='left')
imdb_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48766 entries, 0 to 48765
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             48766 non-null  object
#  1   ordering           48766 non-null  int64
#  2   title              48766 non-null  object
#  3   region             48766 non-null  object
#  4   language           320 non-null    object
#  5   types              3800 non-null   object
#  6   attributes         1440 non-null   object
#  7   is_original_title  48761 non-null  float64
#  8   averagerating      27778 non-null  float64
#  9   numvotes           27778 non-null  float64
#  10  genre_ids          14037 non-null  object
#  11  original_language  14037 non-null  object
#  12  original_title     14037 non-null  object
#  13  popularity         14037 non-null  float64
#  14  release_date       14037 non-null  object
#  15  vote_average       14037 non-null  float64
#  16  vote_count         14037 non-null  float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 6.7+ MB

# %%
print(f'those two merged have {len(imdb_tmdb)} records')
# Out:
# those two merged have 48766 records

# %% [markdown]
# ** see what data was lost and try to find pattern in what was lost

# %%
imdb_df['title'].value_counts()[:50]
# Out:
# Gone                                        9
# Broken                                      9
# The Return                                  9
# Collision                                   7
# Lucky                                       7
# Home                                        7
# Vengeance                                   6
# Freedom                                     6
# Writer's Block                              6
# Closure                                     6
# Stuck                                       6
# Aftermath                                   6
# The Other Side                              6
# Revenge                                     6
# Dead End                                    6
# Homecoming                                  6
# I Am                                        5
# Unfinished Business                         5
# The Truth                                   5
# Recovery                                    5
# Thieves                                     5
# Lights Out                                  5
# Happy                                       5
# The List                                    5
# Breaking Point                              5
# Trapped                                     5
# Love                                        5
# Redemption                                  5
# The Harvest                                 5
# Catalyst                                    5
# Retribution                                 5
# Paradise                                    5
# The Family                                  5
# Transit                                     5
# Breathe                                     4
# Hope                                        4
# Bad Blood                                   4
# Anna                                        4
# After                                       4
# Dreams                                      4
# Flowers                                     4
# The Void                                    4
# Untitled Sony Pictures Animation Project    4
# The Mountain                                4
# Twelve                                      4
# The Price                                   4
# Run                                         4
# The Gift                                    4
# Alone                                       4
# Rush                                        4
# Name: title, dtype: int64

# %% [markdown]
# ## Dropping Duplicates

# %%
imdb_df = imdb_df.drop_duplicates(subset=['tconst'], keep='first')

# %%
imdb_df['title'].value_counts()[:50]
# Out:
# Gone                                        9
# Broken                                      9
# The Return                                  9
# Collision                                   7
# Lucky                                       7
# Home                                        7
# Vengeance                                   6
# Freedom                                     6
# Writer's Block                              6
# Closure                                     6
# Stuck                                       6
# Aftermath                                   6
# The Other Side                              6
# Revenge                                     6
# Dead End                                    6
# Homecoming                                  6
# I Am                                        5
# Unfinished Business                         5
# The Truth                                   5
# Recovery                                    5
# Thieves                                     5
# Lights Out                                  5
# Happy                                       5
# The List                                    5
# Breaking Point                              5
# Trapped                                     5
# Love                                        5
# Redemption                                  5
# The Harvest                                 5
# Catalyst                                    5
# Retribution                                 5
# Paradise                                    5
# The Family                                  5
# Transit                                     5
# Breathe                                     4
# Hope                                        4
# Bad Blood                                   4
# Anna                                        4
# After                                       4
# Dreams                                      4
# Flowers                                     4
# The Void                                    4
# Untitled Sony Pictures Animation Project    4
# The Mountain                                4
# Twelve                                      4
# The Price                                   4
# Run                                         4
# The Gift                                    4
# Alone                                       4
# Rush                                        4
# Name: title, dtype: int64

# %%
imdb_df = imdb_df.drop_duplicates(subset=['title'], keep='first')

# %%
imdb_df.keys()
# Out:
# Index(['tconst', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'is_original_title', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44631 entries, 8298 to 331694
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             44631 non-null  object
#  1   ordering           44631 non-null  int64
#  2   title              44631 non-null  object
#  3   region             44631 non-null  object
#  4   language           291 non-null    object
#  5   types              3401 non-null   object
#  6   attributes         1357 non-null   object
#  7   is_original_title  44627 non-null  float64
#  8   averagerating      25268 non-null  float64
#  9   numvotes           25268 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.7+ MB

# %% [markdown]
# ## Dropping extra columns

# %%
#imdb_df = imdb_df.drop(['original_title_y', 'attributes', 'types'], axis=1)

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44631 entries, 8298 to 331694
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             44631 non-null  object
#  1   ordering           44631 non-null  int64
#  2   title              44631 non-null  object
#  3   region             44631 non-null  object
#  4   language           291 non-null    object
#  5   types              3401 non-null   object
#  6   attributes         1357 non-null   object
#  7   is_original_title  44627 non-null  float64
#  8   averagerating      25268 non-null  float64
#  9   numvotes           25268 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.7+ MB

# %%
imdb_df = imdb_df.drop('language', axis=1)
imdb_df
# Out:
#            tconst  ordering                                title region  \
# 8298    tt1375666         8                            Inception     US
# 13595   tt0816692        14                         Interstellar     US
# 47379   tt1853728        11                     Django Unchained     US
# 81125   tt0848228        36                         The Avengers     US
# 94472   tt0993846        12              The Wolf of Wall Street     US
# ...           ...       ...                                  ...    ...
# 331539  tt7385718         1                         Conway Pride     US
# 331574  tt8855960         1                          Straight Up     US
# 331582  tt8901666         1                    The Journey Ahead     US
# 331686  tt9705860         1  Dusan Vukotic Croatian Oscar Winner     US
# 331694  tt9755806         1                            Big Shark     US
#
#               types attributes  is_original_title  averagerating   numvotes
# 8298            NaN        NaN                0.0            8.8  1841066.0
# 13595           NaN        NaN                0.0            8.6  1299334.0
# 47379   imdbDisplay        NaN                0.0            8.4  1211405.0
# 81125   imdbDisplay        NaN                0.0            8.1  1183655.0
# 94472   imdbDisplay        NaN                0.0            8.2  1035358.0
# ...             ...        ...                ...            ...        ...
# 331539          NaN        NaN                0.0            NaN        NaN
# 331574          NaN        NaN                0.0            NaN        NaN
# 331582  imdbDisplay        NaN                0.0            NaN        NaN
# 331686  imdbDisplay        NaN                0.0            NaN        NaN
# 331694          NaN        NaN                0.0            NaN        NaN
#
# [44631 rows x 9 columns]

# %%
imdb_df.describe()
# Out:
#            ordering  is_original_title  averagerating      numvotes
# count  44631.000000       44627.000000   25268.000000  2.526800e+04
# mean       2.087249           0.000022       6.269867  8.373305e+03
# std        3.440093           0.004734       1.586310  4.926036e+04
# min        1.000000           0.000000       1.000000  5.000000e+00
# 25%        1.000000           0.000000       5.200000  1.500000e+01
# 50%        1.000000           0.000000       6.400000  6.500000e+01
# 75%        1.000000           0.000000       7.400000  5.240000e+02
# max       52.000000           1.000000      10.000000  1.841066e+06

# %%
imdb_df['is_original_title'].value_counts()
# Out:
# 0.0    44626
# 1.0        1
# Name: is_original_title, dtype: int64

# %%
imdb_df['numvotes'].mean()
# Out:
# 8373.304772835207

# %% [markdown]
# ## Initial Exploration of Correlations and Visualizations

# %%
imdb_df.corr()
# Out:
#                    ordering  is_original_title  averagerating  numvotes
# ordering           1.000000           0.001256      -0.029204  0.520178
# is_original_title  0.001256           1.000000      -0.007019 -0.000980
# averagerating     -0.029204          -0.007019       1.000000  0.072255
# numvotes           0.520178          -0.000980       0.072255  1.000000

# %%
imdb_df
# Out:
#            tconst  ordering                                title region  \
# 8298    tt1375666         8                            Inception     US
# 13595   tt0816692        14                         Interstellar     US
# 47379   tt1853728        11                     Django Unchained     US
# 81125   tt0848228        36                         The Avengers     US
# 94472   tt0993846        12              The Wolf of Wall Street     US
# ...           ...       ...                                  ...    ...
# 331539  tt7385718         1                         Conway Pride     US
# 331574  tt8855960         1                          Straight Up     US
# 331582  tt8901666         1                    The Journey Ahead     US
# 331686  tt9705860         1  Dusan Vukotic Croatian Oscar Winner     US
# 331694  tt9755806         1                            Big Shark     US
#
#               types attributes  is_original_title  averagerating   numvotes
# 8298            NaN        NaN                0.0            8.8  1841066.0
# 13595           NaN        NaN                0.0            8.6  1299334.0
# 47379   imdbDisplay        NaN                0.0            8.4  1211405.0
# 81125   imdbDisplay        NaN                0.0            8.1  1183655.0
# 94472   imdbDisplay        NaN                0.0            8.2  1035358.0
# ...             ...        ...                ...            ...        ...
# 331539          NaN        NaN                0.0            NaN        NaN
# 331574          NaN        NaN                0.0            NaN        NaN
# 331582  imdbDisplay        NaN                0.0            NaN        NaN
# 331686  imdbDisplay        NaN                0.0            NaN        NaN
# 331694          NaN        NaN                0.0            NaN        NaN
#
# [44631 rows x 9 columns]

# %% [markdown]
# Filtering to get ratings greater than zero and number of votes from movies with more than at least the mean count of votes

# %%
imdb_df['numvotes'].mean()
# Out:
# 8373.304772835207

# %%
imdb_df_avg_num = imdb_df[imdb_df['averagerating'] > 0]
imdb_df_avg_num = imdb_df[imdb_df['numvotes'] >= imdb_df['numvotes'].mean()]

# %%
imdb_df_avg_num.corr()
# Out:
#                    ordering  is_original_title  averagerating  numvotes
# ordering           1.000000                NaN       0.103908  0.337581
# is_original_title       NaN                NaN            NaN       NaN
# averagerating      0.103908                NaN       1.000000  0.372103
# numvotes           0.337581                NaN       0.372103  1.000000

# %%
fig, ax = plt.subplots()
ax.scatter(imdb_df_avg_num['numvotes'], imdb_df_avg_num['averagerating'],  alpha=.3)

# %% [markdown]
# Here we are exploring the correlation between vote average, vote count, and popularity in the movies database

# %%
tmdb_movies.corr()
# Out:
#               popularity  vote_average  vote_count
# popularity      1.000000      0.065273    0.694849
# vote_average    0.065273      1.000000    0.086370
# vote_count      0.694849      0.086370    1.000000

# %%
fig, ax = plt.subplots()
ax.scatter(tmdb_movies['popularity'], tmdb_movies['vote_count'], alpha=.3)

# %%
fig, ax = plt.subplots()
ax.scatter(tmdb_movies['vote_average'], tmdb_movies['vote_count'], alpha=.3)

# %% [markdown]
# ## Combining Names and Job to IMDB to get Correlation Between Certain Names and Ratings

# %%
imdb_crew
# Out:
#            tconst                      directors              writers
# 0       tt0285252                      nm0899854            nm0899854
# 1       tt0438973                            NaN  nm0175726,nm1802864
# 2       tt0462036                      nm1940585            nm1940585
# 3       tt0835418                      nm0151540  nm0310087,nm0841532
# 4       tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...           ...                            ...                  ...
# 146139  tt8999974                     nm10122357           nm10122357
# 146140  tt9001390                      nm6711477            nm6711477
# 146141  tt9001494          nm10123242,nm10123248                  NaN
# 146142  tt9004986                      nm4993825            nm4993825
# 146143  tt9010172                            NaN            nm8352242
#
# [146144 rows x 3 columns]

# %%
imdb_name_basics
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
#                                known_for_titles
# 0       tt0837562,tt2398241,tt0844471,tt0118553
# 1       tt0896534,tt6791238,tt0287072,tt1682940
# 2       tt1470654,tt0363631,tt0104030,tt0102898
# 3       tt0114371,tt2004304,tt1618448,tt1224387
# 4       tt0452644,tt0452692,tt3458030,tt2178256
# ...                                         ...
# 606643                                      NaN
# 606644                      tt9090932,tt8737130
# 606645                      tt8734436,tt9615610
# 606646                                      NaN
# 606647                                tt8743182
#
# [606648 rows x 6 columns]

# %%
imdb_principals
# Out:
#             tconst  ordering      nconst  category       job  \
# 0        tt0111414         1   nm0246005     actor       NaN
# 1        tt0111414         2   nm0398271  director       NaN
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor       NaN
# 4        tt0323808         1   nm3579312   actress       NaN
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor       NaN
# 1028182  tt9692684         2   nm4929530      self       NaN
# 1028183  tt9692684         3  nm10441594  director       NaN
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4            ["Beth Boothby"]
# ...                       ...
# 1028181  ["Ebenezer Scrooge"]
# 1028182   ["Herself","Regan"]
# 1028183                   NaN
# 1028184                   NaN
# 1028185                   NaN
#
# [1028186 rows x 6 columns]

# %%
people_df = pd.merge(imdb_principals, imdb_name_basics, on='nconst', how='inner')
people_df

# %%
people_df.info()

# %% [markdown]
# Below we dropped birth_year and death_year as we aren't exploring that relation. We then dropped characters, jobs, and primary_profession because category defines the job already and has a full amount of information for the set.

# %%
people_df.drop('birth_year', axis=1, inplace=True)
people_df.drop('death_year', axis=1, inplace=True)

# %%
people_df

# %%
people_df.drop('job', axis=1, inplace=True)
people_df.drop('characters', axis=1, inplace=True)
people_df.drop('primary_profession', axis=1, inplace=True)

# %%
people_df

# %%
imdb_df_people_df = pd.merge(imdb_df, people_df, on='tconst', how='left')
imdb_df_people_df

# %% [markdown]
# ## exploring category of each job type to see what names have average ratings

# %%
imdb_df_people_df['category'].value_counts()

# %% [markdown]
# ## people category vs ratings

# %% [markdown]
# Using category director and producer to find relations against top ratings

# %%
producer_df = imdb_df_people_df[imdb_df_people_df['category'] == 'producer']
producer_df

# %%
grouped_high_rating_producers = producer_df.sort_values(by='averagerating', ascending=False)
grouped_high_rating_producers

# %%
grouped_high_rating_producers_mean = grouped_high_rating_producers[grouped_high_rating_producers['numvotes'] >= grouped_high_rating_producers['numvotes'].mean()]
grouped_high_rating_producers_mean

# %%
grouped_high_rating_producers_mean['primary_name'].value_counts()

# %%
producer_mean_rating = grouped_high_rating_producers_mean.groupby('primary_name').mean()

# %%
producer_mean_rating[:20]

# %% [markdown]
# Upon further investigation to the top names, we concluded that we can suggest Lynda Obst to be a producer for a wide variety of films that return high ratings and Siddharth Roy Kapur in the international market for Bollywood films. We can recommend Erin Leyden, Tamara Rosenberg, Deirdre FEnton, Libby Geist, and Nina Krstic for social justice/commentary films.

# %%
producer_mean_rating.sort_values(by='averagerating', ascending=False, inplace=True)

# %%
producer_mean_rating.loc['Jason Blum']

# %%
x = grouped_high_rating_producers_mean['primary_name'].value_counts().index[:20]
x

# %%
y = grouped_high_rating_producers_mean['primary_name'].value_counts().values[:20]
y

# %%
fig, ax = plt.subplots()
ax.bar(x, y)
ax.set_xlabel('Producer Name')
ax.set_ylabel('How many movies')
ax.set_title('# of movies per producer')

# %%
x_mean = producer_mean_rating['averagerating'].index[:20]
x_mean

# %%
y_mean = producer_mean_rating['averagerating'].values[:20]
y_mean

# %%
fig, ax = plt.subplots()
ax.bar(x_mean, y_mean)

# %%
fig, ax = plt.subplots()
ax.scatter(producer_mean_rating['averagerating'])

# %%
#high_rating_producers = imdb_df_people_df[imdb_df_people_df_df['averagerating'] == ]

# %% [markdown]
# scatter between values

# %%
x = composer_df['primary_name'].value_counts()
x

# %%
y = composer_df['primary_name'].value_counts().index
y

# %%
fig, ax = plt.subplots()
ax.barh(x, y)

# %%
fig, ax = plt.subplots()
ax.scatter(tmdb_movies['vote_count'], tmdb_movies['vote_average'], alpha=.3)

# %%
fig, ax = plt.subplots()
ax.scatter(tmdb_movies['vote_count'], tmdb_movies['vote_average'], alpha=.3)

# %%
#tmdb_movies['release_date'] = pd.to_datetime(tmdb_movies['release_date'])
#tmdb_movies['release_date']

# %%
#tmdb_movies.sort_values(by='release_date')

# %%
#tmdb_movies_years = tmdb_movies[tmdb_movies['release_date'] >= '1980-01-01']
#tmdb_movies_years.sort_values(by='release_date')

# %%
#fig, ax = plt.subplots()
#ax.plot(tmdb_movies['release_date'], tmdb_movies['popularity'])

# %% [markdown]
# see correlation between $$ spent and return - scatter

# %%
tnumbers_db_df = pd.read_csv('../zippedData/tn.movie_budgets.csv.gz', index_col=0)
tnumbers_db_df

# %%
imdb_df

# %%
imdb_df.head[:60]

# %%
tnumbers_db_df.rename(columns = {'movie': 'title'}, inplace=True)
tnumbers_db_df

# %%
joined_imdb_tndb = pd.merge(imdb_df_people_df, tnumbers_db_df, on='title', how='inner')
joined_imdb_tndb

# %%
joined_imdb_tndb.drop('types', axis=1, inplace=True)

# %%
joined_imdb_tndb.drop('attributes', axis=1, inplace=True)

# %%
joined_imdb_tndb.drop('ordering_x', axis=1, inplace=True)

# %%
joined_imdb_tndb

# %%
tn_df['domestic_gross'] = tn_df['domestic_gross'].str.replace(',','')
tn_df['domestic_gross'] = tn_df['domestic_gross'].str.replace('$','')
tn_df['domestic_gross'] = tn_df['domestic_gross'].astype(float)

# %%
joined_imdb_tndb['production_budget'] = joined_imdb_tndb['production_budget'].str.replace(',','')
joined_imdb_tndb['production_budget'] = joined_imdb_tndb['production_budget'].str.replace('$','')
joined_imdb_tndb['production_budget'] = joined_imdb_tndb['production_budget'].astype(float)

# %%
joined_imdb_tndb['domestic_gross'] = joined_imdb_tndb['domestic_gross'].str.replace(',','')
joined_imdb_tndb['domestic_gross'] = joined_imdb_tndb['domestic_gross'].str.replace('$','')
joined_imdb_tndb['domestic_gross'] = joined_imdb_tndb['domestic_gross'].astype(float)

# %%
joined_imdb_tndb['worldwide_gross'] = joined_imdb_tndb['worldwide_gross'].str.replace(',','')
joined_imdb_tndb['worldwide_gross'] = joined_imdb_tndb['worldwide_gross'].str.replace('$','')
joined_imdb_tndb['worldwide_gross'] = joined_imdb_tndb['worldwide_gross'].astype(float)

# %%
joined_imdb_tndb.info()

# %%
joined_imdb_tndb['gross_budget_ratio'] = joined_imdb_tndb['production_budget'] / joined_imdb_tndb['worldwide_gross']
joined_imdb_tndb['gross_budget_ratio']

# %%
joined_director_df = joined_imdb_tndb[joined_imdb_tndb['category'] == 'director']

# %%
joined_director_df

# %%
joined_director_df.sort_values(by='averagerating', ascending=False)

# %%
joined_director_df.isna().sum()

# %%
cleaned_joined_director_df = joined_director_df.dropna(subset=['averagerating'])
cleaned_joined_director_df.isna().sum()

# %%
cleaned_joined_director_df

# %%
cleaned_joined_director_df['worldwide_gross'].value_counts()

# %%
cleaned_joined_director_df.loc[cleaned_joined_director_df['primary_name'] == 'Nitesh Tiwari']

# %%
cleaned_joined_director_df = cleaned_joined_director_df[cleaned_joined_director_df['worldwide_gross'] > 0]

# %%
fig, ax = plt.subplots()
ax.scatter(cleaned_joined_director_df['averagerating'], cleaned_joined_director_df['worldwide_gross'], alpha=.2)

# %%
cleaned_joined_director_df.corr()

# %% [markdown]
# In the plot below, we can see that there's a slightly positive correlation between average rating and worldwide gross. We can also observe that many low budget

# %%
fig, ax = plt.subplots()
ax.scatter(cleaned_joined_director_df['worldwide_gross'], cleaned_joined_director_df['averagerating'], alpha=.1)

# %%
fig, ax = plt.subplots()
ax.scatter(cleaned_joined_director_df['averagerating'], cleaned_joined_director_df['production_budget'], alpha=.1)

# %%
fig, ax = plt.subplots()
ax.scatter(cleaned_joined_director_df['domestic_gross'], cleaned_joined_director_df['averagerating'], alpha=.1)

# %%
fig, ax = plt.subplots()
ax.scatter(cleaned_joined_director_df['worldwide_gross'], cleaned_joined_director_df['production_budget'], alpha=.2)

# %%
cleaned_joined_director_df = cleaned_joined_director_df[cleaned_joined_director_df['numvotes'] >= cleaned_joined_director_df['numvotes'].mean()]

# %%
cleaned_joined_director_df_mean = cleaned_joined_director_df.groupby('primary_name').mean()

# %%
cleaned_joined_director_df_mean.sort_values(by='averagerating', ascending=False)

# %%
fig, ax = plt.subplots()
ax.scatter(cleaned_joined_director_df_mean['worldwide_gross'], cleaned_joined_director_df_mean['production_budget'], alpha=.2)

# %%
fig, ax = plt.subplots()
ax.scatter(cleaned_joined_director_df_mean['averagerating'], cleaned_joined_director_df_mean['production_budget'], alpha=.2)
