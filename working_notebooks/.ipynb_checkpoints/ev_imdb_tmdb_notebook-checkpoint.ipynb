# %% [markdown]
# ## IMDB /TMDB Notebook

# %% [markdown]
# In this notebook, we will use data from Box Office Mojo, IMDB, Rotten Tomatoes, TheMovieDB, and The Numbers to gain insight on how the new Microsoft Movie studio should proceed in content creation to maximize ratings, reviews, and profit. The data we are using is important and helpful to this case because the information within the data can help us narrow down which genres of movies were well received and yielded higher ratings and grossed higher earnings.

# %% [markdown]
# So it looks like we need to join/merge the different tables so we can get the names/ratings/reviews etc matching
#
# ratings with titles on tconstant
#
# once we have the titles we can join the other sets that have the movie names

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !ls
# Out:
# ev_imdb_tmdb_notebook.ipynb
# project_notebook_ajc.ipynb

# %% [markdown]
# ## Importing Data

# %% [markdown]
# Eyeballing the data sets to see how many data points we have, what we need to change, and how we can merge the sets together to get a better understanding of our data.

# %% [markdown]
# In this set, we have the average ratings for 73,856 and the number of votes for movies/'tconst'.

# %%
imdb_ratings = pd.read_csv('../zippedData/imdb.title.ratings.csv.gz')
imdb_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
imdb_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %% [markdown]
# In this data set, we have the name of different employees in the industry and their profession and what titles they're known for. Unsure of how we can use the birth and death years. Will probably drop those two

# %%
imdb_name_basics = pd.read_csv('../zippeddata/imdb.name.basics.csv.gz')
imdb_name_basics
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
#                                known_for_titles
# 0       tt0837562,tt2398241,tt0844471,tt0118553
# 1       tt0896534,tt6791238,tt0287072,tt1682940
# 2       tt1470654,tt0363631,tt0104030,tt0102898
# 3       tt0114371,tt2004304,tt1618448,tt1224387
# 4       tt0452644,tt0452692,tt3458030,tt2178256
# ...                                         ...
# 606643                                      NaN
# 606644                      tt9090932,tt8737130
# 606645                      tt8734436,tt9615610
# 606646                                      NaN
# 606647                                tt8743182
#
# [606648 rows x 6 columns]

# %% [markdown]
# In this data set, we have those same employees on 'nconst' with a more defined category of their position on each movie title 'tconst'. This set seems more useful to define what movies a certain person worked on to see the successs of a movie in relation to the artist.

# %%
imdb_principals = pd.read_csv('../zippeddata/imdb.title.principals.csv.gz')
imdb_principals
# Out:
#             tconst  ordering      nconst  category       job  \
# 0        tt0111414         1   nm0246005     actor       NaN
# 1        tt0111414         2   nm0398271  director       NaN
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor       NaN
# 4        tt0323808         1   nm3579312   actress       NaN
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor       NaN
# 1028182  tt9692684         2   nm4929530      self       NaN
# 1028183  tt9692684         3  nm10441594  director       NaN
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4            ["Beth Boothby"]
# ...                       ...
# 1028181  ["Ebenezer Scrooge"]
# 1028182   ["Herself","Regan"]
# 1028183                   NaN
# 1028184                   NaN
# 1028185                   NaN
#
# [1028186 rows x 6 columns]

# %% [markdown]
# This dataset has the names of the movies in relation to the title_id/'tconst'. We can use the 'title_id' renamed as 'tconst' to merge the sets together.

# %%
imdb_akas = pd.read_csv('../zippeddata/imdb.title.akas.csv.gz')
imdb_akas
# Out:
#          title_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg          NaN          NaN                0.0
# 1           NaN  imdbDisplay          NaN                0.0
# 2           NaN  imdbDisplay          NaN                0.0
# 3           NaN          NaN  short title                0.0
# 4           NaN  imdbDisplay          NaN                0.0
# ...         ...          ...          ...                ...
# 331698      NaN     original          NaN                1.0
# 331699       en  imdbDisplay          NaN                0.0
# 331700      NaN     original          NaN                1.0
# 331701      NaN          NaN          NaN                0.0
# 331702       en  imdbDisplay          NaN                0.0
#
# [331703 rows x 8 columns]

# %%
imdb_akas.rename(columns = {'title_id': 'tconst'}, inplace=True)
imdb_akas
# Out:
#            tconst  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg          NaN          NaN                0.0
# 1           NaN  imdbDisplay          NaN                0.0
# 2           NaN  imdbDisplay          NaN                0.0
# 3           NaN          NaN  short title                0.0
# 4           NaN  imdbDisplay          NaN                0.0
# ...         ...          ...          ...                ...
# 331698      NaN     original          NaN                1.0
# 331699       en  imdbDisplay          NaN                0.0
# 331700      NaN     original          NaN                1.0
# 331701      NaN          NaN          NaN                0.0
# 331702       en  imdbDisplay          NaN                0.0
#
# [331703 rows x 8 columns]

# %% [markdown]
# This dataset has the directors and writers associated with each movie.

# %%
imdb_crew = pd.read_csv('../zippedData/imdb.title.crew.csv.gz')
imdb_crew
# Out:
#            tconst                      directors              writers
# 0       tt0285252                      nm0899854            nm0899854
# 1       tt0438973                            NaN  nm0175726,nm1802864
# 2       tt0462036                      nm1940585            nm1940585
# 3       tt0835418                      nm0151540  nm0310087,nm0841532
# 4       tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...           ...                            ...                  ...
# 146139  tt8999974                     nm10122357           nm10122357
# 146140  tt9001390                      nm6711477            nm6711477
# 146141  tt9001494          nm10123242,nm10123248                  NaN
# 146142  tt9004986                      nm4993825            nm4993825
# 146143  tt9010172                            NaN            nm8352242
#
# [146144 rows x 3 columns]

# %% [markdown]
# This data set has genre_ids as integers. We should try to find the associating genre with the ID. It also shows the popularity, releae date, average, and vote count for different movies.

# %%
tmdb_movies = pd.read_csv('../zippedData/tmdb.movies.csv.gz', index_col=0)
tmdb_movies = tmdb_movies.drop('id', axis=1)
tmdb_movies
# Out:
#                  genre_ids original_language  \
# 0          [12, 14, 10751]                en
# 1      [14, 12, 16, 10751]                en
# 2            [12, 28, 878]                en
# 3          [16, 35, 10751]                en
# 4            [28, 878, 12]                en
# ...                    ...               ...
# 26512             [27, 18]                en
# 26513             [18, 53]                en
# 26514         [14, 28, 12]                en
# 26515      [10751, 12, 28]                en
# 26516             [53, 27]                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 8 columns]

# %% [markdown]
# ## Merging IMDB Ratings Dataset with IMDB Titles

# %% [markdown]
# Here we are merging the IMDB name/titles set with the ratings.

# %%
imdb_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   tconst             331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB

# %%
imdb_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
imdb_df = pd.merge(imdb_akas, imdb_ratings, on='tconst', how='left')
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331703 entries, 0 to 331702
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   tconst             331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
#  8   averagerating      261806 non-null  float64
#  9   numvotes           261806 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 27.8+ MB

# %% [markdown]
# ## Filtering out duplicated/foreign names

# %% [markdown]
# Below we can see we have multiple names for a single move as it was released in several different markets. We want to isolate and get a single movie title we're familiar with and use that one. We made the decision to subset the US region to get a standard US release title. We filtered out all the different types of release titles as well.

# %%
imdb_df
# Out:
#            tconst  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title  averagerating  \
# 0            bg          NaN          NaN                0.0            7.0
# 1           NaN  imdbDisplay          NaN                0.0            7.0
# 2           NaN  imdbDisplay          NaN                0.0            7.0
# 3           NaN          NaN  short title                0.0            7.0
# 4           NaN  imdbDisplay          NaN                0.0            7.0
# ...         ...          ...          ...                ...            ...
# 331698      NaN     original          NaN                1.0            7.7
# 331699       en  imdbDisplay          NaN                0.0            7.7
# 331700      NaN     original          NaN                1.0            NaN
# 331701      NaN          NaN          NaN                0.0            NaN
# 331702       en  imdbDisplay          NaN                0.0            NaN
#
#         numvotes
# 0       539338.0
# 1       539338.0
# 2       539338.0
# 3       539338.0
# 4       539338.0
# ...          ...
# 331698       6.0
# 331699       6.0
# 331700       NaN
# 331701       NaN
# 331702       NaN
#
# [331703 rows x 10 columns]

# %% [markdown]
# As you can see below, some tconst's have multiple listings for the same unique movie ID

# %%
imdb_df['tconst'].value_counts()
# Out:
# tt2488496    61
# tt2310332    55
# tt1201607    55
# tt2948356    53
# tt2278871    53
#              ..
# tt4951988     1
# tt1773325     1
# tt5902118     1
# tt7172260     1
# tt2720050     1
# Name: tconst, Length: 122302, dtype: int64

# %% [markdown]
# We sort the set descending by the average rating to get the higher rating of the movie for each 'tconst'

# %%
imdb_df = imdb_df.sort_values(by='averagerating', ascending=False)

# %% [markdown]
# Here we are subsetting the US region.

# %%
imdb_df = imdb_df[imdb_df['region'] == 'US']

# %%
imdb_df = imdb_df[imdb_df['attributes'] != 'fake working title']
imdb_df = imdb_df[imdb_df['attributes'] != 'informal short title']
imdb_df = imdb_df[imdb_df['attributes'] != 'promotional title']
imdb_df = imdb_df[imdb_df['types'] != 'working']
imdb_df = imdb_df[imdb_df['attributes'] != 'IMAX version']
imdb_df = imdb_df[imdb_df['attributes'] != 'poster title']
imdb_df = imdb_df[imdb_df['attributes'] != 'informal title']
imdb_df = imdb_df[imdb_df['attributes'] != '3-D version']
imdb_df = imdb_df[imdb_df['attributes'] != 'director\'s cut']
imdb_df = imdb_df[imdb_df['attributes'] != 'alternative spelling']
imdb_df = imdb_df[imdb_df['attributes'] != 'informal alternative title']
imdb_df = imdb_df[imdb_df['attributes'] != 'long title']
imdb_df = imdb_df[imdb_df['attributes'] != 'short title']
imdb_df = imdb_df[imdb_df['types'] != 'alternative']

# %%
imdb_df = imdb_df.sort_values(by='language', ascending =True)

# %%
imdb_df = imdb_df.sort_values(by='numvotes', ascending=False)
imdb_df
# Out:
#            tconst  ordering                                title region  \
# 8270    tt1375666        24                            Inception     US
# 8298    tt1375666         8                            Inception     US
# 13612   tt0816692         2                         Interstellar     US
# 13595   tt0816692        14                         Interstellar     US
# 47379   tt1853728        11                     Django Unchained     US
# ...           ...       ...                                  ...    ...
# 331539  tt7385718         1                         Conway Pride     US
# 331574  tt8855960         1                          Straight Up     US
# 331582  tt8901666         1                    The Journey Ahead     US
# 331686  tt9705860         1  Dusan Vukotic Croatian Oscar Winner     US
# 331694  tt9755806         1                            Big Shark     US
#
#        language        types attributes  is_original_title  averagerating  \
# 8270        NaN  imdbDisplay        NaN                0.0            8.8
# 8298         en          NaN        NaN                0.0            8.8
# 13612        en          NaN        NaN                0.0            8.6
# 13595       NaN          NaN        NaN                0.0            8.6
# 47379       NaN  imdbDisplay        NaN                0.0            8.4
# ...         ...          ...        ...                ...            ...
# 331539      NaN          NaN        NaN                0.0            NaN
# 331574      NaN          NaN        NaN                0.0            NaN
# 331582      NaN  imdbDisplay        NaN                0.0            NaN
# 331686      NaN  imdbDisplay        NaN                0.0            NaN
# 331694      NaN          NaN        NaN                0.0            NaN
#
#          numvotes
# 8270    1841066.0
# 8298    1841066.0
# 13612   1299334.0
# 13595   1299334.0
# 47379   1211405.0
# ...           ...
# 331539        NaN
# 331574        NaN
# 331582        NaN
# 331686        NaN
# 331694        NaN
#
# [47807 rows x 10 columns]

# %%
imdb_df.iloc[100:150]
# Out:
#            tconst  ordering                                      title region  \
# 162484  tt4154796        18                          Avengers: Endgame     US
# 61129   tt2310332        49  The Hobbit: The Battle of the Five Armies     US
# 33829   tt1570728        22                       Crazy, Stupid, Love.     US
# 191396  tt3783958        41                                 La La Land     US
# 94347   tt3460252        25                          The Hateful Eight     US
# 480     tt1343092        13                           The Great Gatsby     US
# 59893   tt1411697        16                       The Hangover Part II     US
# 80772   tt1229238        38       Mission: Impossible - Ghost Protocol     US
# 51786   tt2250912         6                     Spider-Man: Homecoming     US
# 16792   tt0470752        11                                 Ex Machina     US
# 10211   tt1659337        28            The Perks of Being a Wallflower     US
# 25315   tt1800241        31                            American Hustle     US
# 57003   tt2872718        29                               Nightcrawler     US
# 131879  tt1291584         8                                    Warrior     US
# 122408  tt0790636        19                         Dallas Buyers Club     US
# 53964   tt2179136        17                            American Sniper     US
# 71630   tt1430132         6                              The Wolverine     US
# 178105  tt5052448        15                                    Get Out     US
# 10997   tt1840309         9                                  Divergent     US
# 45619   tt1499658        14                            Horrible Bosses     US
# 76198   tt1457767         3                              The Conjuring     US
# 76181   tt1457767        24                              The Conjuring     US
# 102021  tt1535108        10                                    Elysium     US
# 33630   tt1515091        14         Sherlock Holmes: A Game of Shadows     US
# 114177  tt1979320         6                                       Rush     US
# 26918   tt1454029        23                                   The Help     US
# 233743  tt5463162        11                                        DP2     US
# 233770  tt5463162         5                                 Deadpool 2     US
# 233757  tt5463162        24                                 Deadpool 2     US
# 233772  tt5463162         7                       Once Upon a Deadpool     US
# 102968  tt2103281        18             Dawn of the Planet of the Apes     US
# 6075    tt1872181        14                   The Amazing Spider-Man 2     US
# 73850   tt1568346        39            The Girl with the Dragon Tattoo     US
# 73836   tt1568346        26            The Girl with the Dragon Tattoo     US
# 45710   tt1535109        18                           Captain Phillips     US
# 32129   tt1790864        21                            The Maze Runner     US
# 169655  tt2948356        32                                   Zootopia     US
# 158012  tt2713180         2                                       Fury     US
# 37298   tt1951265        19      The Hunger Games: Mockingjay - Part 1     US
# 130397  tt1856101        18                          Blade Runner 2049     US
# 130412  tt1856101        31                          Blade Runner 2049     US
# 60374   tt1723121        35                          We're the Millers     US
# 51696   tt2245084        16                                 Big Hero 6     US
# 79219   tt2119532        25                              Hacksaw Ridge     US
# 59873   tt1399103         8                                   D.O.T.M.     US
# 59866   tt1399103        47             Transformers: Dark of the Moon     US
# 59860   tt1399103        41             Transformers: Dark of the Moon     US
# 99004   tt0398286        16                                    Tangled     US
# 73328   tt3183660         6    Fantastic Beasts and Where to Find Them     US
# 6170    tt1895587        26                                  Spotlight     US
#
#        language        types                attributes  is_original_title  \
# 162484       en          NaN                       NaN                0.0
# 61129       NaN  imdbDisplay                       NaN                0.0
# 33829       NaN          NaN                       NaN                0.0
# 191396      NaN  imdbDisplay                       NaN                0.0
# 94347       NaN  imdbDisplay                       NaN                0.0
# 480         NaN  imdbDisplay                       NaN                0.0
# 59893       NaN  imdbDisplay                       NaN                0.0
# 80772       NaN          NaN                       NaN                0.0
# 51786       NaN          NaN                       NaN                0.0
# 16792       NaN  imdbDisplay                       NaN                0.0
# 10211       NaN  imdbDisplay                       NaN                0.0
# 25315       NaN          NaN                       NaN                0.0
# 57003       NaN  imdbDisplay                       NaN                0.0
# 131879      NaN  imdbDisplay                       NaN                0.0
# 122408      NaN  imdbDisplay                       NaN                0.0
# 53964       NaN  imdbDisplay                       NaN                0.0
# 71630       NaN          NaN                       NaN                0.0
# 178105      NaN  imdbDisplay                       NaN                0.0
# 10997       NaN  imdbDisplay                       NaN                0.0
# 45619       NaN          NaN                       NaN                0.0
# 76198        en          NaN                       NaN                0.0
# 76181       NaN          NaN                       NaN                0.0
# 102021      NaN  imdbDisplay                       NaN                0.0
# 33630       NaN          NaN                       NaN                0.0
# 114177      NaN  imdbDisplay                       NaN                0.0
# 26918       NaN  imdbDisplay                       NaN                0.0
# 233743      NaN          NaN  promotional abbreviation                0.0
# 233770       en          NaN                       NaN                0.0
# 233757      NaN          NaN                       NaN                0.0
# 233772      NaN          NaN               cut version                0.0
# 102968      NaN          NaN                       NaN                0.0
# 6075        NaN          NaN                       NaN                0.0
# 73850        en          NaN                       NaN                0.0
# 73836       NaN  imdbDisplay                       NaN                0.0
# 45710       NaN  imdbDisplay                       NaN                0.0
# 32129       NaN  imdbDisplay                       NaN                0.0
# 169655      NaN  imdbDisplay                       NaN                0.0
# 158012      NaN          NaN                       NaN                0.0
# 37298       NaN          NaN                       NaN                0.0
# 130397      NaN          NaN                       NaN                0.0
# 130412       en          NaN                       NaN                0.0
# 60374       NaN  imdbDisplay                       NaN                0.0
# 51696       NaN  imdbDisplay                       NaN                0.0
# 79219       NaN  imdbDisplay                       NaN                0.0
# 59873       NaN          NaN  promotional abbreviation                0.0
# 59866       NaN          NaN                       NaN                0.0
# 59860        en          NaN                       NaN                0.0
# 99004       NaN  imdbDisplay                       NaN                0.0
# 73328       NaN  imdbDisplay                       NaN                0.0
# 6170        NaN  imdbDisplay                       NaN                0.0
#
#         averagerating  numvotes
# 162484            8.8    441135
# 61129             7.4    438621
# 33829             7.4    436830
# 191396            8.0    436070
# 94347             7.8    434966
# 480               7.3    433165
# 59893             6.5    432800
# 80772             7.4    428142
# 51786             7.5    426302
# 16792             7.7    424542
# 10211             8.0    422671
# 25315             7.2    418221
# 57003             7.9    404476
# 131879            8.2    403755
# 122408            8.0    402462
# 53964             7.3    401915
# 71630             6.7    401286
# 178105            7.7    400474
# 10997             6.7    399703
# 45619             6.9    398695
# 76198             7.5    397233
# 76181             7.5    397233
# 102021            6.6    395572
# 33630             7.5    394189
# 114177            8.1    393437
# 26918             8.1    392699
# 233743            7.8    391735
# 233770            7.8    391735
# 233757            7.8    391735
# 233772            7.8    391735
# 102968            7.6    390199
# 6075              6.6    388363
# 73850             7.8    387580
# 73836             7.8    387580
# 45710             7.8    387402
# 32129             6.8    387038
# 169655            8.0    383446
# 158012            7.6    381993
# 37298             6.6    379050
# 130397            8.0    376241
# 130412            8.0    376241
# 60374             7.0    371759
# 51696             7.8    371204
# 79219             8.1    366904
# 59873             6.2    366409
# 59866             6.2    366409
# 59860             6.2    366409
# 99004             7.8    366366
# 73328             7.3    365353
# 6170              8.1    365110

# %%
imdb_df = imdb_df.drop_duplicates(subset=['tconst'], keep='first')
imdb_df
# Out:
#            tconst  ordering  \
# 7285    tt1375666        24
# 11968   tt0816692         2
# 41792   tt1853728        11
# 71288   tt0848228        39
# 82656   tt0993846        12
# ...           ...       ...
# 145620  tt3187586         1
# 4188    tt1899109         1
# 147110  tt4949388         1
# 213220  tt4254746         1
# 200573  tt7497230         1
#
#                                                     title region language  \
# 7285                                            Inception     US      NaN
# 11968                                        Interstellar     US       en
# 41792                                    Django Unchained     US      NaN
# 71288                               Marvel's The Avengers     US      NaN
# 82656                             The Wolf of Wall Street     US      NaN
# ...                                                   ...    ...      ...
# 145620                                                 11     US      NaN
# 4188                                          Abomination     US      NaN
# 147110                                  Baby Frankenstein     US      NaN
# 213220                                 Lone Star Holy War     US      NaN
# 200573  Duchess of Windsor: The Woman Who Stole the Ki...     US      NaN
#
#               types      attributes  is_original_title  averagerating  \
# 7285    imdbDisplay             NaN                0.0            8.8
# 11968           NaN             NaN                0.0            8.6
# 41792   imdbDisplay             NaN                0.0            8.4
# 71288           NaN  complete title                0.0            8.1
# 82656   imdbDisplay             NaN                0.0            8.2
# ...             ...             ...                ...            ...
# 145620          NaN             NaN                0.0            6.2
# 4188            NaN             NaN                0.0            7.8
# 147110          NaN             NaN                0.0            7.8
# 213220          NaN             NaN                0.0            7.8
# 200573          NaN             NaN                0.0            3.6
#
#         numvotes
# 7285     1841066
# 11968    1299334
# 41792    1211405
# 71288    1183655
# 82656    1035358
# ...          ...
# 145620         5
# 4188           5
# 147110         5
# 213220         5
# 200573         5
#
# [26050 rows x 10 columns]

# %% [markdown]
# ## Merging the Movies Database to our IMDB dataframe on Title

# %% [markdown]
# Here we merged the two different datasets to get the other information to match in the table

# %%
tmdb_movies
# Out:
#                  genre_ids original_language  \
# 0          [12, 14, 10751]                en
# 1      [14, 12, 16, 10751]                en
# 2            [12, 28, 878]                en
# 3          [16, 35, 10751]                en
# 4            [28, 878, 12]                en
# ...                    ...               ...
# 26512             [27, 18]                en
# 26513             [18, 53]                en
# 26514         [14, 28, 12]                en
# 26515      [10751, 12, 28]                en
# 26516             [53, 27]                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 8 columns]

# %%
tmdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   original_language  26517 non-null  object
#  2   original_title     26517 non-null  object
#  3   popularity         26517 non-null  float64
#  4   release_date       26517 non-null  object
#  5   title              26517 non-null  object
#  6   vote_average       26517 non-null  float64
#  7   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.8+ MB

# %%
tmdb_movies_sorted = tmdb_movies['title'] == tmdb_movies['original_title']
tmdb_movies_sorted.value_counts()
# Out:
# True     23973
# False     2544
# dtype: int64

# %%
#missmatching_titles = []
#for movie in tmdb_movies:
 #   if tmdb_movies['original_title'] != tmdb_movies['title']:
 #       missmatching_titles.append(movie)
        
#Missmatching_titles

# %%
tmdb_movies['original_title'][100:150]
# Out:
# 100                              The Next Three Days
# 101                            Kung Fu Panda Holiday
# 102                                           Buried
# 103                                                乱
# 104                               Operation: Endgame
# 105                               Gulliver's Travels
# 106    Legend of the Guardians: The Owls of Ga'Hoole
# 107                                The Spy Next Door
# 108                                       Jackass 3D
# 109                                  The Babysitters
# 110                          Banlieue 13 - Ultimatum
# 111                                           [REC]²
# 112                                    Open Season 3
# 113                                    Morning Glory
# 114                                      Harry Brown
# 115         Cats & Dogs: The Revenge of Kitty Galore
# 116                                      The Fighter
# 117                                          9 Songs
# 118                                      The Tourist
# 119                     The Cutting Edge: Fire & Ice
# 120                                 Forbidden Planet
# 121                         Barbie in A Mermaid Tale
# 122                                               葉問
# 123                                          Killers
# 124                                        You Again
# 125                                            Devil
# 126                                       The Losers
# 127                                   Animal Kingdom
# 128                  Wall Street: Money Never Sleeps
# 129                                         Monsters
# 130                             Hot Tub Time Machine
# 131                       A Matter of Loaf and Death
# 132                               Love & Other Drugs
# 133                                        16 Wishes
# 134                                  Never Let Me Go
# 135                       It's Kind of a Funny Story
# 136                                    Eat Pray Love
# 137                               Sex and the City 2
# 138                                       Four Lions
# 139                                     When in Rome
# 140                                The Bounty Hunter
# 141                                    Winter's Bone
# 142                              Waiting for Forever
# 143                                  My Soul to Take
# 144                        A Nightmare on Elm Street
# 145                                          Flipped
# 146                                        Let Me In
# 147                                      Unthinkable
# 148                                           Frozen
# 149                  Smokin' Aces 2: Assassins' Ball
# Name: original_title, dtype: object

# %%
tmdb_movies['title'][200:250]
# Out:
# 200                          Elena Undone
# 201                             The Final
# 202                            Hatchet II
# 203                 Louis C.K.: Hilarious
# 204                                  Ca$h
# 205                             Marmaduke
# 206                  Get Him to the Greek
# 207                                  Womb
# 208                      London Boulevard
# 209                                Twelve
# 210                               Redline
# 211                The Kids Are All Right
# 212           BloodRayne: The Third Reich
# 213                               Peacock
# 214           Don't Be Afraid of the Dark
# 215                       The Illusionist
# 216                                 Stone
# 217                 Welcome to the Rileys
# 218                                Rubber
# 219                               Bunraku
# 220                    Going the Distance
# 221                          Julia's Eyes
# 222                     The Warrior's Way
# 223                            Last Night
# 224                               Get Low
# 225                         Loose Cannons
# 226                          The Runaways
# 227                           Bloomington
# 228                 Paranormal Activity 2
# 229    Tom and Jerry Meet Sherlock Holmes
# 230              Mesrine: Killer Instinct
# 231            Mega Shark vs. Crocosaurus
# 232                              Metropia
# 233                       The Company Men
# 234                       Alpha and Omega
# 235                           Avalon High
# 236           30 Days of Night: Dark Days
# 237              Minions: Orientation Day
# 238                           Planet Hulk
# 239                                    13
# 240                  Survival of the Dead
# 241         The Solitude of Prime Numbers
# 242                             14 Blades
# 243           Barbie: A Fashion Fairytale
# 244                            Sharktopus
# 245                        Burning Bright
# 246                             Hereafter
# 247                       All Good Things
# 248                              Defendor
# 249                              The Dead
# Name: title, dtype: object

# %%
imdb_df = pd.merge(imdb_df, tmdb_movies, on='title', how='inner')
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12719 entries, 0 to 12718
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             12719 non-null  object
#  1   ordering           12719 non-null  int64
#  2   title              12719 non-null  object
#  3   region             12719 non-null  object
#  4   language           115 non-null    object
#  5   types              1822 non-null   object
#  6   attributes         291 non-null    object
#  7   is_original_title  12719 non-null  float64
#  8   averagerating      12719 non-null  float64
#  9   numvotes           12719 non-null  int64
#  10  genre_ids          12719 non-null  object
#  11  original_language  12719 non-null  object
#  12  original_title     12719 non-null  object
#  13  popularity         12719 non-null  float64
#  14  release_date       12719 non-null  object
#  15  vote_average       12719 non-null  float64
#  16  vote_count         12719 non-null  int64
# dtypes: float64(4), int64(3), object(10)
# memory usage: 1.7+ MB

# %%
imdb_df

# %% [markdown]
# ** see what data was lost and try to find pattern in what was lost

# %%
imdb_df['title'].value_counts()[:50]
# Out:
# The Return        6
# Dead End          6
# Lucky             6
# Aftermath         5
# Stuck             5
# Homecoming        5
# Broken            5
# Refuge            4
# Writer's Block    4
# Closure           4
# The Other Side    4
# Lights Out        4
# Paradise          4
# Bully             4
# The Family        4
# Delirium          4
# Love              4
# Escape Room       3
# Noah              3
# Truth or Dare     3
# Redemption        3
# Fake              3
# Truth             3
# Trapped           3
# Do Not Disturb    3
# Another World     3
# Shelter           3
# Bigfoot           3
# Opening Night     3
# Home              3
# Finding Home      3
# Get a Job         3
# Frankenstein      3
# Bastard           3
# Collapse          3
# After             3
# The Stray         3
# The Throwaways    3
# Abduction         3
# Recovery          3
# Blue              3
# The Girl          3
# Turning Point     3
# Wild              3
# Rio               3
# The Pact          3
# The Price         3
# Anna              3
# Misfire           3
# The Basement      3
# Name: title, dtype: int64

# %% [markdown]
# ## Dropping Duplicates

# %%
imdb_df = imdb_df.drop_duplicates(subset=['tconst'], keep='first')

# %%
imdb_df['title'].value_counts()[:50]
# Out:
# The Return        6
# Dead End          6
# Lucky             6
# Aftermath         5
# Stuck             5
# Homecoming        5
# Broken            5
# Refuge            4
# Writer's Block    4
# Closure           4
# The Other Side    4
# Lights Out        4
# Paradise          4
# Bully             4
# The Family        4
# Delirium          4
# Love              4
# Escape Room       3
# Noah              3
# Truth or Dare     3
# Redemption        3
# Fake              3
# Truth             3
# Trapped           3
# Do Not Disturb    3
# Another World     3
# Shelter           3
# Bigfoot           3
# Opening Night     3
# Home              3
# Finding Home      3
# Get a Job         3
# Frankenstein      3
# Bastard           3
# Collapse          3
# After             3
# The Stray         3
# The Throwaways    3
# Abduction         3
# Recovery          3
# Blue              3
# The Girl          3
# Turning Point     3
# Wild              3
# Rio               3
# The Pact          3
# The Price         3
# Anna              3
# Misfire           3
# The Basement      3
# Name: title, dtype: int64

# %%
imdb_df = imdb_df.drop_duplicates(subset=['title'], keep='first')

# %%
imdb_df.keys()
# Out:
# Index(['tconst', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'is_original_title', 'averagerating', 'numvotes',
#        'genre_ids', 'original_language', 'original_title', 'popularity',
#        'release_date', 'vote_average', 'vote_count', 'lucky'],
#       dtype='object')

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26050 entries, 0 to 27772
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             26050 non-null  object
#  1   ordering           26050 non-null  int64
#  2   title              26050 non-null  object
#  3   region             26050 non-null  object
#  4   language           279 non-null    object
#  5   types              3209 non-null   object
#  6   attributes         1200 non-null   object
#  7   is_original_title  26050 non-null  float64
#  8   averagerating      26050 non-null  float64
#  9   numvotes           26050 non-null  int64
#  10  genre_ids          10996 non-null  object
#  11  original_language  10996 non-null  object
#  12  original_title     10996 non-null  object
#  13  popularity         10996 non-null  float64
#  14  release_date       10996 non-null  object
#  15  vote_average       10996 non-null  float64
#  16  vote_count         10996 non-null  float64
#  17  lucky              26050 non-null  bool
# dtypes: bool(1), float64(5), int64(2), object(10)
# memory usage: 3.6+ MB

# %% [markdown]
# ## Dropping extra columns

# %%
imdb_df = imdb_df.drop(['original_title_y', 'attributes', 'types'], axis=1)

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16392 entries, 0 to 16391
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tconst               16392 non-null  object
#  1   averagerating        16392 non-null  float64
#  2   numvotes             16392 non-null  int64
#  3   ordering             16392 non-null  int64
#  4   title                16392 non-null  object
#  5   region               12911 non-null  object
#  6   language             978 non-null    object
#  7   is_original_title    16392 non-null  float64
#  8   genre_ids_x          16392 non-null  object
#  9   original_language_x  16392 non-null  object
#  10  original_title_x     16392 non-null  object
#  11  popularity_x         16392 non-null  float64
#  12  release_date_x       16392 non-null  object
#  13  vote_average_x       16392 non-null  float64
#  14  vote_count_x         16392 non-null  int64
#  15  genre_ids_y          16392 non-null  object
#  16  original_language_y  16392 non-null  object
#  17  popularity_y         16392 non-null  float64
#  18  release_date_y       16392 non-null  object
#  19  vote_average_y       16392 non-null  float64
#  20  vote_count_y         16392 non-null  int64
# dtypes: float64(6), int64(4), object(11)
# memory usage: 2.8+ MB

# %%
imdb_df = imdb_df.drop('language', axis=1)
imdb_df
# Out:
#           tconst  averagerating  numvotes  ordering                   title  \
# 0      tt1043726            4.2     50352        10  The Legend of Hercules
# 1      tt1270291            5.8      5728        10             Hunter Prey
# 2      tt1283887            5.4      2527         1           Burning Palms
# 3      tt1285219            3.4       387         1      Ghosts Don't Exist
# 4      tt1343110            2.5       345         1            Speed-Dating
# ...          ...            ...       ...       ...                     ...
# 16387  tt8439854            6.6      7691         1            Lust Stories
# 16388  tt8564902            4.7      5863         1       Death of a Nation
# 16389  tt8564902            4.7      5863         1       Death of a Nation
# 16390  tt8564902            4.7      5863         1       Death of a Nation
# 16391  tt8564902            4.7      5863         1       Death of a Nation
#
#       region  is_original_title          genre_ids_x original_language_x  \
# 0        NaN                1.0             [28, 12]                  en
# 1        NaN                1.0            [878, 53]                  en
# 2        NaN                1.0      [35, 18, 10751]                  en
# 3         US                0.0             [27, 53]                  en
# 4         US                0.0  [35, 18, 10749, 53]                  en
# ...      ...                ...                  ...                 ...
# 16387     IN                0.0          [18, 10749]                  hi
# 16388     US                0.0                   []                  en
# 16389     US                0.0                   []                  en
# 16390     US                0.0             [99, 36]                  en
# 16391     US                0.0             [99, 36]                  en
#
#              original_title_x  popularity_x release_date_x  vote_average_x  \
# 0      The Legend of Hercules        13.754     2014-01-10             4.5
# 1                 Hunter Prey         3.738     2010-05-01             5.6
# 2               Burning Palms         2.883     2010-04-23             5.6
# 3          Ghosts Don't Exist         1.703     2010-01-01             4.1
# 4                Speed-Dating         1.400     2010-01-01             3.1
# ...                       ...           ...            ...             ...
# 16387            Lust Stories         7.811     2018-06-15             6.6
# 16388       Death of a Nation         0.600     2010-06-27             6.5
# 16389       Death of a Nation         0.600     2010-06-27             6.5
# 16390       Death of a Nation         2.254     2018-08-03             5.5
# 16391       Death of a Nation         2.254     2018-08-03             5.5
#
#        vote_count_x          genre_ids_y original_language_y  popularity_y  \
# 0               805             [28, 12]                  en        13.754
# 1                51            [878, 53]                  en         3.738
# 2                27      [35, 18, 10751]                  en         2.883
# 3                 5             [27, 53]                  en         1.703
# 4                 6  [35, 18, 10749, 53]                  en         1.400
# ...             ...                  ...                 ...           ...
# 16387            46          [18, 10749]                  hi         7.811
# 16388             1                   []                  en         0.600
# 16389             1             [99, 36]                  en         2.254
# 16390            12                   []                  en         0.600
# 16391            12             [99, 36]                  en         2.254
#
#       release_date_y  vote_average_y  vote_count_y
# 0         2014-01-10             4.5           805
# 1         2010-05-01             5.6            51
# 2         2010-04-23             5.6            27
# 3         2010-01-01             4.1             5
# 4         2010-01-01             3.1             6
# ...              ...             ...           ...
# 16387     2018-06-15             6.6            46
# 16388     2010-06-27             6.5             1
# 16389     2018-08-03             5.5            12
# 16390     2010-06-27             6.5             1
# 16391     2018-08-03             5.5            12
#
# [16392 rows x 20 columns]

# %%
imdb_df.describe()
# Out:
#        averagerating       numvotes      ordering  is_original_title  \
# count   16392.000000   16392.000000  16392.000000       16392.000000
# mean        5.921822    4753.583638      1.693997           0.198939
# std         1.444242   31203.935488      2.400978           0.399214
# min         1.100000       5.000000      1.000000           0.000000
# 25%         4.900000      40.000000      1.000000           0.000000
# 50%         6.100000     169.000000      1.000000           0.000000
# 75%         7.000000     657.000000      1.000000           0.000000
# max         9.700000  820847.000000     10.000000           1.000000
#
#        popularity_x  vote_average_x  vote_count_x  popularity_y  \
# count  16392.000000    16392.000000  16392.000000  16392.000000
# mean       2.932109        5.768631    166.149036      2.932109
# std        3.989803        1.812935    864.093307      3.989803
# min        0.600000        0.000000      1.000000      0.600000
# 25%        0.600000        4.800000      2.000000      0.600000
# 50%        1.307000        5.900000      5.000000      1.307000
# 75%        3.427000        7.000000     26.000000      3.427000
# max       80.773000       10.000000  20175.000000     80.773000
#
#        vote_average_y  vote_count_y
# count    16392.000000  16392.000000
# mean         5.768631    166.149036
# std          1.812935    864.093307
# min          0.000000      1.000000
# 25%          4.800000      2.000000
# 50%          5.900000      5.000000
# 75%          7.000000     26.000000
# max         10.000000  20175.000000

# %%
imdb_df['is_original_title'].value_counts()
# Out:
# 0.0    13131
# 1.0     3261
# Name: is_original_title, dtype: int64

# %%
imdb_df['numvotes'].mean()
# Out:
# 4753.583638360175

# %% [markdown]
# ## Initial Exploration of Correlations and Visualizations

# %%
imdb_df.corr()
# Out:
#                    averagerating  numvotes  ordering  is_original_title  \
# averagerating           1.000000  0.100131  0.081662          -0.090955
# numvotes                0.100131  1.000000  0.451827           0.011925
# ordering                0.081662  0.451827  1.000000           0.018642
# is_original_title      -0.090955  0.011925  0.018642           1.000000
# popularity_x            0.050239  0.438464  0.394557           0.036408
# vote_average_x          0.400200  0.072903  0.070332          -0.017113
# vote_count_x            0.068997  0.591530  0.244202          -0.016769
# popularity_y            0.050239  0.438464  0.394557           0.036408
# vote_average_y          0.400200  0.072903  0.070332          -0.017113
# vote_count_y            0.068997  0.591530  0.244202          -0.016769
#
#                    popularity_x  vote_average_x  vote_count_x  popularity_y  \
# averagerating          0.050239        0.400200      0.068997      0.050239
# numvotes               0.438464        0.072903      0.591530      0.438464
# ordering               0.394557        0.070332      0.244202      0.394557
# is_original_title      0.036408       -0.017113     -0.016769      0.036408
# popularity_x           1.000000        0.102993      0.681310      0.750740
# vote_average_x         0.102993        1.000000      0.104022      0.086027
# vote_count_x           0.681310        0.104022      1.000000      0.504188
# popularity_y           0.750740        0.086027      0.504188      1.000000
# vote_average_y         0.086027        0.826002      0.083587      0.102993
# vote_count_y           0.504188        0.083587      0.735481      0.681310
#
#                    vote_average_y  vote_count_y
# averagerating            0.400200      0.068997
# numvotes                 0.072903      0.591530
# ordering                 0.070332      0.244202
# is_original_title       -0.017113     -0.016769
# popularity_x             0.086027      0.504188
# vote_average_x           0.826002      0.083587
# vote_count_x             0.083587      0.735481
# popularity_y             0.102993      0.681310
# vote_average_y           1.000000      0.104022
# vote_count_y             0.104022      1.000000

# %%
imdb_df
# Out:
#            tconst  ordering  \
# 7285    tt1375666        24
# 11968   tt0816692         2
# 41792   tt1853728        11
# 71288   tt0848228        39
# 82656   tt0993846        12
# ...           ...       ...
# 145620  tt3187586         1
# 4188    tt1899109         1
# 147110  tt4949388         1
# 213220  tt4254746         1
# 200573  tt7497230         1
#
#                                                     title region language  \
# 7285                                            Inception     US      NaN
# 11968                                        Interstellar     US       en
# 41792                                    Django Unchained     US      NaN
# 71288                               Marvel's The Avengers     US      NaN
# 82656                             The Wolf of Wall Street     US      NaN
# ...                                                   ...    ...      ...
# 145620                                                 11     US      NaN
# 4188                                          Abomination     US      NaN
# 147110                                  Baby Frankenstein     US      NaN
# 213220                                 Lone Star Holy War     US      NaN
# 200573  Duchess of Windsor: The Woman Who Stole the Ki...     US      NaN
#
#               types      attributes  is_original_title  averagerating  \
# 7285    imdbDisplay             NaN                0.0            8.8
# 11968           NaN             NaN                0.0            8.6
# 41792   imdbDisplay             NaN                0.0            8.4
# 71288           NaN  complete title                0.0            8.1
# 82656   imdbDisplay             NaN                0.0            8.2
# ...             ...             ...                ...            ...
# 145620          NaN             NaN                0.0            6.2
# 4188            NaN             NaN                0.0            7.8
# 147110          NaN             NaN                0.0            7.8
# 213220          NaN             NaN                0.0            7.8
# 200573          NaN             NaN                0.0            3.6
#
#         numvotes
# 7285     1841066
# 11968    1299334
# 41792    1211405
# 71288    1183655
# 82656    1035358
# ...          ...
# 145620         5
# 4188           5
# 147110         5
# 213220         5
# 200573         5
#
# [26050 rows x 10 columns]

# %% [markdown]
# Filtering to get ratings greater than zero and number of votes from movies with more than at least the mean count of votes

# %%
imdb_df['numvotes'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6eb16d62ff28> in <module>
# ----> 1 imdb_df['numvotes'].mean()
#
# NameError: name 'imdb_df' is not defined

# %%
imdb_df_avg_num = imdb_df[imdb_df['averagerating'] > 0]
imdb_df_avg_num = imdb_df[imdb_df['numvotes'] > imdb_df['numvotes'].mean()]

# %%
fig, ax = plt.subplots()
ax.scatter(imdb_df['averagerating'], imdb_df['vote_count_y'], alpha=.3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-3696cfd1d2d4> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.scatter(imdb_df['averagerating'], tmdb_movies['vote_count'], alpha=.3)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4439         y = np.ma.ravel(y)
#    4440         if x.size != y.size:
# -> 4441             raise ValueError("x and y must be the same size")
#    4442
#    4443         if s is None:
#
# ValueError: x and y must be the same size

# %%
fig, ax = plt.subplots()
ax.scatter(imdb_df['vote_count_y'], imdb_df['averagerating'], alpha=.3)

# %%
fig, ax = plt.subplots()
ax.scatter(imdb_df_avg_num['averagerating'], imdb_df_avg_num['numvotes'], alpha=.3)

# %%
fig, ax = plt.subplots()
ax.scatter(imdb_df['averagerating'], imdb_df['popularity_y'], alpha=.3)

# %%
fig, ax = plt.subplots()
ax.scatter(imdb_df['vote_average_y'], imdb_df['numvotes'], alpha=.3)

# %%
fig, ax = plt.subplots()
ax.scatter(imdb_df['popularity_y'], imdb_df['numvotes'], alpha=.3)

# %%
imdb_df['release_date'] = pd.to_datetime(imdb_df['release_date_y'])
groupbys = imdb_df.groupby('averagerating').mean()
groupbys.sort_values(by='averagerating', ascending=False)
# Out:
#                   numvotes  ordering  is_original_title  popularity_x  \
# averagerating
# 9.7              15.500000       1.0           0.000000      3.187500
# 9.4             314.000000       1.0           0.333333      3.443667
# 9.3            2894.833333       1.0           0.333333      0.738333
# 9.2              16.115385       1.0           0.076923      2.483154
# 9.1              62.708333       1.0           0.000000      1.650542
# ...                    ...       ...                ...           ...
# 1.5             264.666667       1.0           0.000000      1.303333
# 1.4             296.333333       1.0           0.000000      1.491667
# 1.3             252.000000       1.0           0.500000      0.600000
# 1.2             134.250000       1.0           0.000000      1.060000
# 1.1             187.666667       1.0           0.000000      1.648667
#
#                vote_average_x  vote_count_x  popularity_y  vote_average_y  \
# averagerating
# 9.7                  8.000000      7.500000      3.187500        8.000000
# 9.4                  7.266667     45.333333      3.443667        7.266667
# 9.3                  4.383333      2.166667      0.738333        4.383333
# 9.2                  6.942308     59.461538      2.483154        6.942308
# 9.1                  6.625000     19.166667      1.650542        6.625000
# ...                       ...           ...           ...             ...
# 1.5                  2.266667      5.000000      1.303333        2.266667
# 1.4                  4.166667      4.000000      1.491667        4.166667
# 1.3                  1.000000      1.500000      0.600000        1.000000
# 1.2                  4.775000      5.500000      1.060000        4.775000
# 1.1                  1.133333      4.666667      1.648667        1.133333
#
#                vote_count_y
# averagerating
# 9.7                7.500000
# 9.4               45.333333
# 9.3                2.166667
# 9.2               59.461538
# 9.1               19.166667
# ...                     ...
# 1.5                5.000000
# 1.4                4.000000
# 1.3                1.500000
# 1.2                5.500000
# 1.1                4.666667
#
# [85 rows x 9 columns]

# %% [markdown]
# ## Combining Names and Job to IMDB to get Correlation Between Certain Names and Ratings

# %%
imdb_crew
# Out:
#            tconst                      directors              writers
# 0       tt0285252                      nm0899854            nm0899854
# 1       tt0438973                            NaN  nm0175726,nm1802864
# 2       tt0462036                      nm1940585            nm1940585
# 3       tt0835418                      nm0151540  nm0310087,nm0841532
# 4       tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...           ...                            ...                  ...
# 146139  tt8999974                     nm10122357           nm10122357
# 146140  tt9001390                      nm6711477            nm6711477
# 146141  tt9001494          nm10123242,nm10123248                  NaN
# 146142  tt9004986                      nm4993825            nm4993825
# 146143  tt9010172                            NaN            nm8352242
#
# [146144 rows x 3 columns]

# %%
imdb_name_basics
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
#                                known_for_titles
# 0       tt0837562,tt2398241,tt0844471,tt0118553
# 1       tt0896534,tt6791238,tt0287072,tt1682940
# 2       tt1470654,tt0363631,tt0104030,tt0102898
# 3       tt0114371,tt2004304,tt1618448,tt1224387
# 4       tt0452644,tt0452692,tt3458030,tt2178256
# ...                                         ...
# 606643                                      NaN
# 606644                      tt9090932,tt8737130
# 606645                      tt8734436,tt9615610
# 606646                                      NaN
# 606647                                tt8743182
#
# [606648 rows x 6 columns]

# %%
imdb_principals
# Out:
#             tconst  ordering      nconst  category       job  \
# 0        tt0111414         1   nm0246005     actor       NaN
# 1        tt0111414         2   nm0398271  director       NaN
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor       NaN
# 4        tt0323808         1   nm3579312   actress       NaN
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor       NaN
# 1028182  tt9692684         2   nm4929530      self       NaN
# 1028183  tt9692684         3  nm10441594  director       NaN
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4            ["Beth Boothby"]
# ...                       ...
# 1028181  ["Ebenezer Scrooge"]
# 1028182   ["Herself","Regan"]
# 1028183                   NaN
# 1028184                   NaN
# 1028185                   NaN
#
# [1028186 rows x 6 columns]

# %%
people_df = pd.merge(imdb_principals, imdb_name_basics, on='nconst', how='inner')
people_df
# Out:
#             tconst  ordering      nconst  category       job   characters  \
# 0        tt0111414         1   nm0246005     actor       NaN  ["The Man"]
# 1        tt0111414         2   nm0398271  director       NaN          NaN
# 2        tt5573596         5   nm0398271  director       NaN          NaN
# 3        tt0111414         3   nm3739909  producer  producer          NaN
# 4        tt0323808        10   nm0059247    editor       NaN          NaN
# ...            ...       ...         ...       ...       ...          ...
# 1027907  tt9689618         3  nm10439724     actor       NaN          NaN
# 1027908  tt9689618         5  nm10439725  director       NaN          NaN
# 1027909  tt9692684         3  nm10441594  director       NaN          NaN
# 1027910  tt9692684         4   nm6009913    writer    writer          NaN
# 1027911  tt9692684         5  nm10441595  producer  producer          NaN
#
#                   primary_name  birth_year  death_year  \
# 0                 Tommy Dysart         NaN         NaN
# 1                 Frank Howson      1952.0         NaN
# 2                 Frank Howson      1952.0         NaN
# 3        Barry Porter-Robinson         NaN         NaN
# 4                  Sean Barton      1944.0         NaN
# ...                        ...         ...         ...
# 1027907       Phillippe Warner         NaN         NaN
# 1027908           Xavi Herrero         NaN         NaN
# 1027909              Guy Jones         NaN         NaN
# 1027910        Sabrina Mahfouz         NaN         NaN
# 1027911             Simmer Dim         NaN         NaN
#
#                                      primary_profession  \
# 0                                                 actor
# 1                                 actor,writer,producer
# 2                                 actor,writer,producer
# 3                               producer,art_department
# 4        editor,editorial_department,assistant_director
# ...                                                 ...
# 1027907                                             NaN
# 1027908                 director,writer,cinematographer
# 1027909                                        director
# 1027910                                          writer
# 1027911                                        producer
#
#                                 known_for_titles
# 0        tt0093120,tt0076974,tt0084296,tt0077064
# 1        tt0104271,tt0094789,tt0102076,tt0111414
# 2        tt0104271,tt0094789,tt0102076,tt0111414
# 3        tt0290884,tt0101374,tt0111414,tt1566940
# 4        tt0402910,tt1022883,tt0086190,tt0490181
# ...                                          ...
# 1027907                                      NaN
# 1027908                                tt9689618
# 1027909                                      NaN
# 1027910  tt5191128,tt3254170,tt2319282,tt8452302
# 1027911                                tt9692684
#
# [1027912 rows x 11 columns]

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1027912 entries, 0 to 1027911
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   tconst              1027912 non-null  object
#  1   ordering            1027912 non-null  int64
#  2   nconst              1027912 non-null  object
#  3   category            1027912 non-null  object
#  4   job                 177684 non-null   object
#  5   characters          393171 non-null   object
#  6   primary_name        1027912 non-null  object
#  7   birth_year          234048 non-null   float64
#  8   death_year          11843 non-null    float64
#  9   primary_profession  974266 non-null   object
#  10  known_for_titles    997445 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 94.1+ MB

# %%
people_df.drop('birth_year', axis=1, inplace=True)
people_df.drop('death_year', axis=1, inplace=True)

# %%
people_df
# Out:
#             tconst  ordering      nconst  category       job   characters  \
# 0        tt0111414         1   nm0246005     actor       NaN  ["The Man"]
# 1        tt0111414         2   nm0398271  director       NaN          NaN
# 2        tt5573596         5   nm0398271  director       NaN          NaN
# 3        tt0111414         3   nm3739909  producer  producer          NaN
# 4        tt0323808        10   nm0059247    editor       NaN          NaN
# ...            ...       ...         ...       ...       ...          ...
# 1027907  tt9689618         3  nm10439724     actor       NaN          NaN
# 1027908  tt9689618         5  nm10439725  director       NaN          NaN
# 1027909  tt9692684         3  nm10441594  director       NaN          NaN
# 1027910  tt9692684         4   nm6009913    writer    writer          NaN
# 1027911  tt9692684         5  nm10441595  producer  producer          NaN
#
#                   primary_name  \
# 0                 Tommy Dysart
# 1                 Frank Howson
# 2                 Frank Howson
# 3        Barry Porter-Robinson
# 4                  Sean Barton
# ...                        ...
# 1027907       Phillippe Warner
# 1027908           Xavi Herrero
# 1027909              Guy Jones
# 1027910        Sabrina Mahfouz
# 1027911             Simmer Dim
#
#                                      primary_profession  \
# 0                                                 actor
# 1                                 actor,writer,producer
# 2                                 actor,writer,producer
# 3                               producer,art_department
# 4        editor,editorial_department,assistant_director
# ...                                                 ...
# 1027907                                             NaN
# 1027908                 director,writer,cinematographer
# 1027909                                        director
# 1027910                                          writer
# 1027911                                        producer
#
#                                 known_for_titles
# 0        tt0093120,tt0076974,tt0084296,tt0077064
# 1        tt0104271,tt0094789,tt0102076,tt0111414
# 2        tt0104271,tt0094789,tt0102076,tt0111414
# 3        tt0290884,tt0101374,tt0111414,tt1566940
# 4        tt0402910,tt1022883,tt0086190,tt0490181
# ...                                          ...
# 1027907                                      NaN
# 1027908                                tt9689618
# 1027909                                      NaN
# 1027910  tt5191128,tt3254170,tt2319282,tt8452302
# 1027911                                tt9692684
#
# [1027912 rows x 9 columns]

# %%
people_df.drop('job', axis=1, inplace=True)
people_df.drop('characters', axis=1, inplace=True)

# %%
imdb_df
# Out:
#            tconst  ordering                           title region language  \
# 7285    tt1375666        24                       Inception     US      NaN
# 11968   tt0816692         2                    Interstellar     US       en
# 41792   tt1853728        11                Django Unchained     US      NaN
# 71288   tt0848228        39           Marvel's The Avengers     US      NaN
# 82656   tt0993846        12         The Wolf of Wall Street     US      NaN
# ...           ...       ...                             ...    ...      ...
# 18873   tt2364897         6        The Disappointments Room     US      NaN
# 163623  tt6367558        23                    Double Lover     US      NaN
# 69139   tt1318517         8  The Man Who Killed Don Quixote     US      NaN
# 108455  tt0835418        14                  The Babymakers     US      NaN
# 227736  tt4669186         2           Kevin Hart: What Now?     US      NaN
#
#               types      attributes  is_original_title  averagerating  \
# 7285    imdbDisplay             NaN                0.0            8.8
# 11968           NaN             NaN                0.0            8.6
# 41792   imdbDisplay             NaN                0.0            8.4
# 71288           NaN  complete title                0.0            8.1
# 82656   imdbDisplay             NaN                0.0            8.2
# ...             ...             ...                ...            ...
# 18873           NaN             NaN                0.0            3.9
# 163623  imdbDisplay             NaN                0.0            6.2
# 69139   imdbDisplay             NaN                0.0            6.5
# 108455          NaN             NaN                0.0            5.0
# 227736          NaN             NaN                0.0            5.9
#
#         numvotes
# 7285     1841066
# 11968    1299334
# 41792    1211405
# 71288    1183655
# 82656    1035358
# ...          ...
# 18873       8167
# 163623      8160
# 69139       8147
# 108455      8147
# 227736      8134
#
# [2132 rows x 10 columns]

# %%
imdb_df_people_df = pd.merge(imdb_df, people_df, on='tconst', how='inner')
imdb_df_people_df
# Out:
#           tconst  ordering_x                  title region language  \
# 0      tt1375666          24              Inception     US      NaN
# 1      tt1375666          24              Inception     US      NaN
# 2      tt1375666          24              Inception     US      NaN
# 3      tt1375666          24              Inception     US      NaN
# 4      tt1375666          24              Inception     US      NaN
# ...          ...         ...                    ...    ...      ...
# 21187  tt4669186           2  Kevin Hart: What Now?     US      NaN
# 21188  tt4669186           2  Kevin Hart: What Now?     US      NaN
# 21189  tt4669186           2  Kevin Hart: What Now?     US      NaN
# 21190  tt4669186           2  Kevin Hart: What Now?     US      NaN
# 21191  tt4669186           2  Kevin Hart: What Now?     US      NaN
#
#              types attributes  is_original_title  averagerating  numvotes  \
# 0      imdbDisplay        NaN                0.0            8.8   1841066
# 1      imdbDisplay        NaN                0.0            8.8   1841066
# 2      imdbDisplay        NaN                0.0            8.8   1841066
# 3      imdbDisplay        NaN                0.0            8.8   1841066
# 4      imdbDisplay        NaN                0.0            8.8   1841066
# ...            ...        ...                ...            ...       ...
# 21187          NaN        NaN                0.0            5.9      8134
# 21188          NaN        NaN                0.0            5.9      8134
# 21189          NaN        NaN                0.0            5.9      8134
# 21190          NaN        NaN                0.0            5.9      8134
# 21191          NaN        NaN                0.0            5.9      8134
#
#        ordering_y     nconst         category         primary_name  \
# 0               7  nm0001877         composer          Hans Zimmer
# 1               4  nm0913822            actor         Ken Watanabe
# 2               8  nm0002892  cinematographer        Wally Pfister
# 3               1  nm0000138            actor    Leonardo DiCaprio
# 4               3  nm0680983          actress           Ellen Page
# ...           ...        ...              ...                  ...
# 21187           5  nm0806492         director         Leslie Small
# 21188           6  nm1103162         director            Tim Story
# 21189           7  nm1830312           writer           Joey Wells
# 21190          10  nm0088287         producer  Valerie Bleth Sharp
# 21191           9  nm0117865           writer     Brian Buccellato
#
#                                primary_profession  \
# 0            music_department,composer,soundtrack
# 1                         actor,producer,director
# 2      cinematographer,camera_department,director
# 3                           actor,producer,writer
# 4                     actress,producer,soundtrack
# ...                                           ...
# 21187                    director,producer,editor
# 21188                     producer,director,actor
# 21189                  writer,actor,miscellaneous
# 21190   production_manager,producer,miscellaneous
# 21191                       actor,writer,director
#
#                               known_for_titles
# 0      tt0172495,tt0988045,tt5013056,tt1375666
# 1      tt0831387,tt1375666,tt2109248,tt0325710
# 2      tt1375666,tt0468569,tt0482571,tt0372784
# 3      tt0407887,tt0120338,tt0993846,tt1375666
# 4      tt0424136,tt1375666,tt0467406,tt1877832
# ...                                        ...
# 21187  tt0277370,tt0880567,tt7924464,tt0382561
# 21188  tt1621045,tt0120667,tt0316732,tt0303714
# 21189  tt0317521,tt6781982,tt6203758,tt1512122
# 21190  tt0884732,tt0999913,tt0427309,tt1075747
# 21191  tt4170996,tt1621045,tt1172998,tt0828586
#
# [21192 rows x 16 columns]

# %% [markdown]
# ## exploring category of each job type to see what names have a higher correlation to ratings##

# %%
imdb_df_people_df['category'].value_counts()
# Out:
# actor                  5113
# producer               4487
# writer                 3609
# actress                3133
# director               2260
# composer               1151
# cinematographer         692
# editor                  367
# self                    244
# production_designer      99
# archive_footage          36
# archive_sound             1
# Name: category, dtype: int64

# %% [markdown]
# ## people category vs ratings

# %% [markdown]
# Using category to find relations against top ratings

# %%
composer_df = imdb_df_people_df[imdb_df_people_df['category'] == 'composer']
composer_df
# Out:
#           tconst  ordering_x                     title region language  \
# 0      tt1375666          24                 Inception     US      NaN
# 12     tt0816692           2              Interstellar     US       en
# 39     tt0848228          39     Marvel's The Avengers     US      NaN
# 72     tt1431045          21                  Deadpool     US      NaN
# 88     tt1392170          29          The Hunger Games     US      NaN
# ...          ...         ...                       ...    ...      ...
# 21032  tt2461520           4                  Man Down     US      NaN
# 21132  tt5208216          18              Wonderstruck     US      NaN
# 21144  tt2364897           6  The Disappointments Room     US      NaN
# 21155  tt6367558          23              Double Lover     US      NaN
# 21172  tt0835418          14            The Babymakers     US      NaN
#
#              types      attributes  is_original_title  averagerating  \
# 0      imdbDisplay             NaN                0.0            8.8
# 12             NaN             NaN                0.0            8.6
# 39             NaN  complete title                0.0            8.1
# 72             NaN             NaN                0.0            8.0
# 88             NaN             NaN                0.0            7.2
# ...            ...             ...                ...            ...
# 21032          NaN             NaN                0.0            5.9
# 21132          NaN             NaN                0.0            6.2
# 21144          NaN             NaN                0.0            3.9
# 21155  imdbDisplay             NaN                0.0            6.2
# 21172          NaN             NaN                0.0            5.0
#
#        numvotes  ordering_y     nconst  category         primary_name  \
# 0       1841066           7  nm0001877  composer          Hans Zimmer
# 12      1299334           9  nm0001877  composer          Hans Zimmer
# 39      1183655           8  nm0006293  composer       Alan Silvestri
# 72       820847          10  nm0432725  composer            Junkie XL
# 88       795227          10  nm0006133  composer  James Newton Howard
# ...         ...         ...        ...       ...                  ...
# 21032      8254          10  nm0543739  composer        Clint Mansell
# 21132      8167          10  nm0001980  composer       Carter Burwell
# 21144      8167          10  nm0003911  composer          Brian Tyler
# 21155      8160          10  nm0739151  composer       Philippe Rombi
# 21172      8147          10  nm0790481  composer      Edward Shearmur
#
#                          primary_profession  \
# 0      music_department,composer,soundtrack
# 12     music_department,composer,soundtrack
# 39     composer,soundtrack,music_department
# 72     soundtrack,composer,music_department
# 88     music_department,composer,soundtrack
# ...                                     ...
# 21032  composer,soundtrack,music_department
# 21132  composer,music_department,soundtrack
# 21144  composer,music_department,soundtrack
# 21155  composer,music_department,soundtrack
# 21172  composer,music_department,soundtrack
#
#                               known_for_titles
# 0      tt0172495,tt0988045,tt5013056,tt1375666
# 12     tt0172495,tt0988045,tt5013056,tt1375666
# 39     tt0458339,tt0093773,tt0338348,tt0109830
# 72     tt1571234,tt0437086,tt1895315,tt1392190
# 88     tt1392170,tt0360717,tt0468569,tt0372784
# ...                                        ...
# 21032  tt1182345,tt8122018,tt0947798,tt0414993
# 21132  tt1403865,tt2402927,tt0116282,tt5027774
# 21144  tt1300854,tt1013752,tt1059786,tt2395427
# 21155  tt1748122,tt1064932,tt1964624,tt0424205
# 21172  tt0305357,tt0212346,tt0160127,tt0346156
#
# [1151 rows x 16 columns]

# %% [markdown]
# scatter between values

# %%
x = composer_df['primary_name'].value_counts().index
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-e350f7ac7eac> in <module>
# ----> 1 x = composer_df['primary_name'].value_counts().index
#       2 x
#
# NameError: name 'composer_df' is not defined

# %%
y = composer_df['primary_name'].value_counts()
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-11562463a570> in <module>
# ----> 1 y = composer_df['primary_name'].value_counts()
#       2 y
#
# NameError: name 'composer_df' is not defined

# %%
fig, ax = plt.subplots()
ax.scatter(tmdb_movies['popularity'], tmdb_movies['vote_count'], alpha=.3)

# %%
fig, ax = plt.subplots()
ax.scatter(tmdb_movies['vote_count'], tmdb_movies['vote_average'], alpha=.3)

# %%
fig, ax = plt.subplots()
ax.scatter(tmdb_movies['vote_count'], tmdb_movies['vote_average'], alpha=.3)

# %%
tmdb_movies['release_date'] = pd.to_datetime(tmdb_movies['release_date'])
tmdb_movies['release_date']
# Out:
# 0       2010-11-19
# 1       2010-03-26
# 2       2010-05-07
# 3       1995-11-22
# 4       2010-07-16
#            ...
# 26512   2018-10-13
# 26513   2018-05-01
# 26514   2018-10-01
# 26515   2018-06-22
# 26516   2018-10-05
# Name: release_date, Length: 26517, dtype: datetime64[ns]

# %%
tmdb_movies.sort_values(by='release_date')
# Out:
#                           genre_ids original_language  \
# 14335                   [18, 10752]                en
# 21758                      [27, 53]                en
# 3580                [35, 18, 10749]                fr
# 26345                            []                en
# 11192               [18, 36, 10749]                en
# ...                             ...               ...
# 24819                          [18]                en
# 24003                [18, 9648, 53]                en
# 24892                          [99]                en
# 24265                   [10749, 18]                en
# 26057  [27, 80, 80, 80, 80, 80, 80]                en
#
#                            original_title  popularity release_date  \
# 14335      All Quiet on the Western Front       9.583   1930-04-29
# 21758                     The Vampire Bat       2.292   1933-01-21
# 3580                           Le Bonheur       1.653   1936-02-27
# 26345   How Walt Disney Cartoons Are Made       0.600   1939-01-19
# 11192         The Best Years of Our Lives       9.647   1946-12-25
# ...                                   ...         ...          ...
# 24819                       Trial by Fire       4.480   2019-05-17
# 24003  We Have Always Lived in the Castle      14.028   2019-05-17
# 24892             This Changes Everything       3.955   2019-06-28
# 24265                             Ophelia       8.715   2019-06-28
# 26057                   Murdery Christmas       0.840   2020-12-25
#
#                                     title  vote_average  vote_count  \
# 14335      All Quiet on the Western Front           7.8         299
# 21758                     The Vampire Bat           5.6          23
# 3580                           Le Bonheur           8.7           3
# 26345   How Walt Disney Cartoons Are Made           7.3           3
# 11192         The Best Years of Our Lives           7.8         243
# ...                                   ...           ...         ...
# 24819                       Trial by Fire           7.0           3
# 24003  We Have Always Lived in the Castle           5.2          24
# 24892             This Changes Everything           0.0           1
# 24265                             Ophelia           0.0           4
# 26057                   Murdery Christmas           0.0           1
#
#        vote_count_average
# 14335                True
# 21758               False
# 3580                False
# 26345               False
# 11192                True
# ...                   ...
# 24819               False
# 24003               False
# 24892               False
# 24265               False
# 26057               False
#
# [26517 rows x 9 columns]

# %%
tmdb_movies_years = tmdb_movies[tmdb_movies['release_date'] >= '1980-01-01']
tmdb_movies_years.sort_values(by='release_date')
# Out:
#                           genre_ids original_language  \
# 18117                          [27]                en
# 2512            [10402, 35, 28, 80]                en
# 2555                     [9648, 53]                en
# 22417                          [27]                en
# 20327               [16, 35, 10402]                en
# ...                             ...               ...
# 24297                          [18]                en
# 24819                          [18]                en
# 24892                          [99]                en
# 24265                   [10749, 18]                en
# 26057  [27, 80, 80, 80, 80, 80, 80]                en
#
#                  original_title  popularity release_date  \
# 18117     Don't Go in the House       4.308   1980-03-28
# 2512         The Blues Brothers      14.882   1980-06-17
# 2555            Dressed to Kill      12.481   1980-06-25
# 22417             Cathy's Curse       1.126   1980-07-01
# 20327     Hurray for Betty Boop       0.600   1980-11-21
# ...                         ...         ...          ...
# 24297  All Creatures Here Below       8.316   2019-05-17
# 24819             Trial by Fire       4.480   2019-05-17
# 24892   This Changes Everything       3.955   2019-06-28
# 24265                   Ophelia       8.715   2019-06-28
# 26057         Murdery Christmas       0.840   2020-12-25
#
#                           title  vote_average  vote_count  vote_count_average
# 18117     Don't Go in the House           5.6          46               False
# 2512         The Blues Brothers           7.7        1972                True
# 2555            Dressed to Kill           6.8         300                True
# 22417             Cathy's Curse           5.2          14               False
# 20327     Hurray for Betty Boop           6.0           2               False
# ...                         ...           ...         ...                 ...
# 24297  All Creatures Here Below           5.0           5               False
# 24819             Trial by Fire           7.0           3               False
# 24892   This Changes Everything           0.0           1               False
# 24265                   Ophelia           0.0           4               False
# 26057         Murdery Christmas           0.0           1               False
#
# [26478 rows x 9 columns]

# %%
fig, ax = plt.subplots()
ax.plot(tmdb_movies['release_date'], tmdb_movies['popularity'])

# %% [markdown]
# see correlation between $$ spent and return - scatter
